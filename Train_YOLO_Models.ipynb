# %% [markdown]
# <a href="https://colab.research.google.com/github/NicheFruit/NicheFruit.github.io/blob/main/Train_YOLO_Models.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Train YOLO Models in Google Colab
# **Author:** Evan Juras, [EJ Technology Consultants](https://ejtech.io)
#
# **Last updated:** January 3, 2025
#
# **GitHub:** [Train and Deploy YOLO Models](https://github.com/EdjeElectronics/Train-and-Deploy-YOLO-Models)
#
# # Introduction
#
# This notebook uses [Ultralytics](https://docs.ultralytics.com/) to train YOLO11, YOLOv8, or YOLOv5 object detection models with a custom dataset. At the end of this Colab, you'll have a custom YOLO model that you can run on your PC, phone, or edge device like the Raspberry Pi.
#
# <p align=center>
# <img src="https://s3.us-west-1.amazonaws.com/evanjuras.com/img/yolo-model-demo.gif" height="360"><br>
# <i>Custom YOLO candy detection model in action!</i>
# </p>
#
# I created a YouTube video that walks through this guide step by step. I recommend following along with the video while working through this notebook.
#
# <p align=center>
# <a href="https://youtu.be/r0RspiLG260" target="_blank"><img src="https://raw.githubusercontent.com/EdjeElectronics/Train-and-Deploy-YOLO-Models/refs/heads/main/doc/Train_YOLO_Thumbnail2.png" height="240"><br>
# <i>Click here to go to the video!</i></a>
# </p>
#
# **Important note: This notebook will be continuously updated to make sure it works with newer versions of Ultralytics and YOLO. If you see any differences between the YouTube video and this notebook, always follow the notebook!**
#
# ### Working in Colab
# Colab provides a virtual machine in your browser complete with a Linux OS, filesystem, Python environment, and best of all, a free GPU. We'll install PyTorch and Ultralytics in this environment and use it to train our model. Simply click the Play button on sections of code in this notebook to execute them on the virtual machine.
#
# ### Navigation
# To navigate this notebook, use the table of contents in the left sidebar to jump from section to section.

# %% [markdown]
# **Verify NVIDIA GPU Availability**
#
# Make sure you're using a GPU-equipped machine by going to "Runtime" -> "Change runtime type" in the top menu bar, and then selecting one of the GPU options in the Hardware accelerator section. Click Play on the following code block to verify that the NVIDIA GPU is present and ready for training.

# %%
# !nvidia-smi

# %% [markdown]
# #1.&nbsp;Gather and Label Training Images

# %% [markdown]
# Before we start training, we need to gather and label images that will be used for training the object detection model. A good starting point for a proof-of-concept model is 200 images. The training images should have random objects in the image along with the desired objects, and should have a variety of backgrounds and lighting conditions.
#
# There are a couple options for gathering images:
#
#
# *   Build a custom dataset by taking your own pictures of the objects and labeling them (this typically results in the best performance)
# *   Find a pre-made dataset from sources like [Roboflow Universe](), [Kaggle](), or [Google Images V7]()
#
#
# If you want to build your own dataset, there are several tools available for labeling images. One good option is [Label Studio](https://labelstud.io/?utm_source=youtube&utm_medium=video&utm_campaign=edjeelectronics), a free and open-source labeling tool that has a simple workflow while providing capabilities for more advanced features. My YouTube video that walks through this notebook (link to be added soon) shows how to label images with Label Studio.
#
# <p align=center>
# <img src="https://raw.githubusercontent.com/EdjeElectronics/Train-and-Deploy-YOLO-Models/refs/heads/main/doc/label-studio-example.PNG" height="380"><br>
# <i>Example of a candy image labeled with Label Studio.</i>
# </p>
#
# If you used Label Studio to label and export the images, they'll be exported in a `project.zip` file that contains the following:
#
# - An `images` folder containing the images
# - A `labels` folder containing the labels in YOLO annotation format
# - A `classes.txt` labelmap file that contains all the classes
# - A `notes.json` file that contains info specific to Label Studio (this file can be ignored)
#
# If you obtained your dataset from another source (like Roboflow Universe) or used another tool to label your dataset, make sure the files are organized in the same folder structure.
#
# <p align=center>
# <img src="https://raw.githubusercontent.com/EdjeElectronics/Train-and-Deploy-YOLO-Models/refs/heads/main/doc/zipped-data-example.png" height=""><br>
# <i>Organize your data in the folders shown here. See my <a href="https://s3.us-west-1.amazonaws.com/evanjuras.com/resources/candy_data_06JAN25.zip">Candy Detection Dataset</a> for an example.</i>
# </p>
#
# Once you've got your dataset built, put into the file structure shown above, and zipped into `data.zip`, you're ready to move on to the next step.

# %% [markdown]
# # 2.&nbsp;Upload Image Dataset and Prepare Training Data

# %% [markdown]
# Next, we'll upload our dataset and prepare it for training with YOLO. We'll split the dataset into train and validation folders, and we'll automatically generate the configuration file for training the model.

# %% [markdown]
# ## 2.1 Upload images
#
# First, we need to upload the dataset to Colab. Here are a few options for moving the `data.zip` folder into this Colab instance.

# %% [markdown]
# **Option 1. Upload through Google Colab**
#
# Upload the `data.zip` file to the Google Colab instance by clicking the "Files" icon on the left hand side of the browser, and then the "Upload to session storage" icon. Select the zip folder to upload it.
#
# <p>
# <br>
# <img src="https://raw.githubusercontent.com/EdjeElectronics/Train-and-Deploy-YOLO-Models/refs/heads/main/doc/upload-colab-files.png" height="240">
# </p>

# %% [markdown]
# **Option 2. Copy from Google Drive**
#
# You can also upload your images to your personal Google Drive, mount the drive on this Colab session, and copy them over to the Colab filesystem. This option works well if you want to upload the images beforehand so you don't have to wait for them to upload each time you restart this Colab. If you have more than 50MB worth of images, I recommend using this option.
#
# First, upload the `data.zip` file to your Google Drive, and make note of the folder you uploaded them to. Replace `MyDrive/path/to/data.zip` with the path to your zip file. (For example, I uploaded the zip file to folder called "candy-dataset1", so I would use `MyDrive/candy-dataset1/data.zip` for the path). Then, run the following block of code to mount your Google Drive to this Colab session and copy the folder to this filesystem.

# %%
from google.colab import drive
drive.mount('/content/gdrive')

# !cp /content/gdrive/MyDrive/path/to/data.zip /content
# Out:
# ---------------------------------------------------------------------------
# MessageError                              Traceback (most recent call last)
# /tmp/ipython-input-2821402137.py in <cell line: 0>()
#       1 from google.colab import drive
# ----> 2 drive.mount('/content/gdrive')
#       3
#       4 get_ipython().system('cp /content/gdrive/MyDrive/path/to/data.zip /content')
#
# /usr/local/lib/python3.12/dist-packages/google/colab/drive.py in mount(mountpoint, force_remount, timeout_ms, readonly)
#      95 def mount(mountpoint, force_remount=False, timeout_ms=120000, readonly=False):
#      96   """Mount your Google Drive at the specified mountpoint path."""
# ---> 97   return _mount(
#      98       mountpoint,
#      99       force_remount=force_remount,
#
# /usr/local/lib/python3.12/dist-packages/google/colab/drive.py in _mount(mountpoint, force_remount, timeout_ms, ephemeral, readonly)
#     132   )
#     133   if ephemeral:
# --> 134     _message.blocking_request(
#     135         'request_auth',
#     136         request={'authType': 'dfs_ephemeral'},
#
# /usr/local/lib/python3.12/dist-packages/google/colab/_message.py in blocking_request(request_type, request, timeout_sec, parent)
#     174       request_type, request, parent=parent, expect_reply=True
#     175   )
# --> 176   return read_reply_from_input(request_id, timeout_sec)
#
# /usr/local/lib/python3.12/dist-packages/google/colab/_message.py in read_reply_from_input(message_id, timeout_sec)
#     101     ):
#     102       if 'error' in reply:
# --> 103         raise MessageError(reply['error'])
#     104       return reply.get('data', None)
#     105
#
# MessageError: Error: credential propagation was unsuccessful

# %% [markdown]
# **Option 3. Use my candy detection or coin detection dataset**
#
# If you just want to test the process on a pre-made dataset, you can use one of my datasets:
#
# *   [Candy image dataset](https://s3.us-west-1.amazonaws.com/evanjuras.com/resources/candy_data_14DEC24.zip), which contains 162 pictures of popular candies (Skittles, Snickers, etc)
# *   [Coin image dataset](https://s3.us-west-1.amazonaws.com/evanjuras.com/resources/YOLO_coin_data_12DEC30.zip), which contains 750 pictures of US coins (pennies, dimes, nickels, and quarters)
#
# Download one of the datasets by running the following code block. I'll use the candy detection dataset as the example for the rest of the notebook.

# %%
# To use my one of pre-made dataset instead of your own custom dataset, download it here (control which dataset is downloaded by commenting out either line)
# !wget -O /content/data.zip https://s3.us-west-1.amazonaws.com/evanjuras.com/resources/candy_data_06JAN25.zip # Candy dataset
#!wget -O /content/data.zip https://s3.us-west-1.amazonaws.com/evanjuras.com/resources/YOLO_coin_data_12DEC30.zip # Coin dataset

# %% [markdown]
# ## 2.2 Split images into train and validation folders

# %% [markdown]
# At this point, whether you used Option 1, 2, or 3, you should be able to click the folder icon on the left and see your `data.zip` file in the list of files. Next, we'll unzip `data.zip` and create some folders to hold the images. Run the following code block to unzip the data.

# %%
# Unzip images to a custom data folder
# !unzip -q /content/data.zip -d /content/custom_data
# Out:
# replace /content/custom_data/README.roboflow.txt? [y]es, [n]o, [A]ll, [N]one, [r]ename:

# %% [markdown]
# Ultralytics requires a particular folder structure to store training data for models. Ultralytics requires a particular folder structure to store training data for models. The root folder is named “data”. Inside, there are two main folders:
#
# *   **Train**: These are the actual images used to train the model. In one epoch of training, every image in the train set is passed into the neural network. The training algorithm adjusts the network weights to fit the data in the images.
#
#
# *   **Validation**: These images are used to check the model's performance at the end of each training epoch.
#
# In each of these folders is a “images” folder and a “labels” folder, which hold the image files and annotation files respectively.

# %% [markdown]
# I wrote a Python script that will automatically create the required folder structure and randomly move 90% of dataset to the "train" folder and 10% to the "validation" folder. Run the following code block to download and execute the scrpt.

# %%
# !wget -O /content/train_val_split.py https://raw.githubusercontent.com/EdjeElectronics/Train-and-Deploy-YOLO-Models/refs/heads/main/utils/train_val_split.py

# TO DO: Improve robustness of train_val_split.py script so it can handle nested data folders, etc
# !python train_val_split.py --datapath="/content/custom_data" --train_pct=0.9

# %% [markdown]
# # 3.&nbsp;Install Requirements (Ultralytics)
#
# Next, we'll install the Ultralytics library in this Google Colab instance. This Python library will be used to train the YOLO model.

# %%
# !pip install ultralytics
# Out:
# Collecting ultralytics
#   Downloading ultralytics-8.3.204-py3-none-any.whl.metadata (37 kB)
# Requirement already satisfied: numpy>=1.23.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (2.0.2)
# Requirement already satisfied: matplotlib>=3.3.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (3.10.0)
# Requirement already satisfied: opencv-python>=4.6.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (4.12.0.88)
# Requirement already satisfied: pillow>=7.1.2 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (11.3.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (6.0.2)
# Requirement already satisfied: requests>=2.23.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (2.32.4)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (1.16.2)
# Requirement already satisfied: torch>=1.8.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (2.8.0+cu126)
# Requirement already satisfied: torchvision>=0.9.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (0.23.0+cu126)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from ultralytics) (5.9.5)
# Requirement already satisfied: polars in /usr/local/lib/python3.12/dist-packages (from ultralytics) (1.25.2)
# Collecting ultralytics-thop>=2.0.0 (from ultralytics)
#   Downloading ultralytics_thop-2.0.17-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (4.60.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (25.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (3.2.4)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (2.9.0.post0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->ultralytics) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->ultralytics) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->ultralytics) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->ultralytics) (2025.8.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (3.19.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (1.13.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (2.27.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (1.11.1.6)
# Requirement already satisfied: triton==3.4.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (3.4.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.17.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=1.8.0->ultralytics) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=1.8.0->ultralytics) (3.0.2)
# Downloading ultralytics-8.3.204-py3-none-any.whl (1.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 32.5 MB/s eta 0:00:00
# Downloading ultralytics_thop-2.0.17-py3-none-any.whl (28 kB)
# Installing collected packages: ultralytics-thop, ultralytics
# Successfully installed ultralytics-8.3.204 ultralytics-thop-2.0.17

# %% [markdown]
# # 4.&nbsp;Configure Training

# %% [markdown]
# There's one last step before we can run training: we need to create the Ultralytics training configuration YAML file. This file specifies the location of your train and validation data, and it also defines the model's classes. An example configuration file model is available [here](https://github.com/ultralytics/ultralytics/blob/main/ultralytics/cfg/datasets/coco128.yaml).
#
# Run the code block below to automatically generate a `data.yaml` configuration file. Make sure you have a labelmap file located at `custom_data/classes.txt`. If you used Label Studio or one of my pre-made datasets, it should already be present. If you assembled the dataset another way, you may have to manually create the `classes.txt` file (see [here](https://github.com/EdjeElectronics/Train-and-Deploy-YOLO-Models/blob/main/doc/classes.txt) for an example of how it's formatted).

# %%
# Python function to automatically create data.yaml config file
# 1. Reads "classes.txt" file to get list of class names
# 2. Creates data dictionary with correct paths to folders, number of classes, and names of classes
# 3. Writes data in YAML format to data.yaml

import yaml
import os

def create_data_yaml(path_to_classes_txt, path_to_data_yaml):

  # Read class.txt to get class names
  if not os.path.exists(path_to_classes_txt):
    print(f'classes.txt file not found! Please create a classes.txt labelmap and move it to {path_to_classes_txt}')
    return
  with open(path_to_classes_txt, 'r') as f:
    classes = []
    for line in f.readlines():
      if len(line.strip()) == 0: continue
      classes.append(line.strip())
  number_of_classes = len(classes)

  # Create data dictionary
  data = {
      'path': '/content/data',
      'train': 'train/images',
      'val': 'validation/images',
      'nc': number_of_classes,
      'names': classes
  }

  # Write data to YAML file
  with open(path_to_data_yaml, 'w') as f:
    yaml.dump(data, f, sort_keys=False)
  print(f'Created config file at {path_to_data_yaml}')

  return

# Define path to classes.txt and run function
path_to_classes_txt = '/content/custom_data/classes.txt'
path_to_data_yaml = '/content/data.yaml'

create_data_yaml(path_to_classes_txt, path_to_data_yaml)

print('\nFile contents:\n')
# !cat /content/data.yaml
# Out:
# classes.txt file not found! Please create a classes.txt labelmap and move it to /content/custom_data/classes.txt
#
# File contents:
#
# train: ../train/images
# val: ../valid/images
# test: ../test/images
#
# nc: 2
# names: ['green', 'purple']
#
# roboflow:
#   workspace: robo-meeif
#   project: artifacts-decode-xyqak-gn0rz
#   version: 1
#   license: CC BY 4.0
#   url: https://app.roboflow.com/robo-meeif/artifacts-decode-xyqak-gn0rz/1

# %% [markdown]
# # 5.&nbsp;Train Model

# %% [markdown]
# ## 5.1 Training Parameters
# Now that the data is organized and the config file is created, we're ready to start training! First, there are a few important parameters to decide on. Visit my article on [Training YOLO Models Locally](https://www.ejtech.io/learn/train-yolo-models) to learn more about these parameters and how to choose them.
#
# **Model architecture & size (`model`):**
#
# There are several YOLO11 models sizes available to train, including `yolo11n.pt`, `yolo11s.pt`, `yolo11m.pt`, `yolo11l.pt`, and `yolo11xl.pt`. Larger models run slower but have higher accuracy, while smaller models run faster but have lower accuracy. I made a brief YouTube video that compares performance of different YOLO models on a Raspberry Pi 5 and a laptop with a RTX 4050 GPU, [check it out here to get a sense of their speed accuracy](https://youtu.be/_WKS4E9SmkA). If you aren't sure which model size to use, `yolo11s.pt` is a good starting point.
#
# You can also train YOLOv8 or YOLOv5 models by substituting `yolo11` for `yolov8` or `yolov5`.
#
#
# **Number of epochs (`epochs`)**
#
# In machine learning, one “epoch” is one single pass through the full training dataset. Setting the number of epochs dictates how long the model will train for. The best amount of epochs to use depends on the size of the dataset and the model architecture. If your dataset has less than 200 images, a good starting point is 60 epochs. If your dataset has more than 200 images, a good starting point is 40 epochs.
#
#
# **Resolution (`imgsz`)**
#
# Resolution has a large impact on the speed and accuracy of the model: a lower resolution model will have higher speed but less accuracy. YOLO models are typically trained and inferenced at a 640x640 resolution. However, if you want your model to run faster or know you will be working with low-resolution images, try using a lower resolution like 480x480.

# %% [markdown]
# ## 5.2 Run Training!

# %% [markdown]
# Run the following code block to begin training. If you want to use a different model, number of epochs, or resolution, change `model`, `epochs`, or `imgsz`.

# %%
# !yolo detect train data=/content/data.yaml model=yolo11s.pt epochs=60 imgsz=640
# Out:
# Ultralytics 8.3.204 🚀 Python-3.12.11 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# engine/trainer: agnostic_nms=False, amp=True, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=/content/data.yaml, degrees=0.0, deterministic=True, device=None, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=60, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolo11s.pt, momentum=0.937, mosaic=1.0, multi_scale=False, name=train4, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=100, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=None, rect=False, resume=False, retina_masks=False, save=True, save_conf=False, save_crop=False, save_dir=/content/runs/detect/train4, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# Overriding model.yaml nc=80 with nc=2
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       928  ultralytics.nn.modules.conv.Conv             [3, 32, 3, 2]
#   1                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   2                  -1  1     26080  ultralytics.nn.modules.block.C3k2            [64, 128, 1, False, 0.25]
#   3                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#   4                  -1  1    103360  ultralytics.nn.modules.block.C3k2            [128, 256, 1, False, 0.25]
#   5                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#   6                  -1  1    346112  ultralytics.nn.modules.block.C3k2            [256, 256, 1, True]
#   7                  -1  1   1180672  ultralytics.nn.modules.conv.Conv             [256, 512, 3, 2]
#   8                  -1  1   1380352  ultralytics.nn.modules.block.C3k2            [512, 512, 1, True]
#   9                  -1  1    656896  ultralytics.nn.modules.block.SPPF            [512, 512, 5]
#  10                  -1  1    990976  ultralytics.nn.modules.block.C2PSA           [512, 512, 1]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  1    443776  ultralytics.nn.modules.block.C3k2            [768, 256, 1, False]
#  14                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  15             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  16                  -1  1    127680  ultralytics.nn.modules.block.C3k2            [512, 128, 1, False]
#  17                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  18            [-1, 13]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  19                  -1  1    345472  ultralytics.nn.modules.block.C3k2            [384, 256, 1, False]
#  20                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#  21            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  22                  -1  1   1511424  ultralytics.nn.modules.block.C3k2            [768, 512, 1, True]
#  23        [16, 19, 22]  1    820182  ultralytics.nn.modules.head.Detect           [2, [128, 256, 512]]
# YOLO11s summary: 181 layers, 9,428,566 parameters, 9,428,550 gradients, 21.6 GFLOPs
#
# Transferred 493/499 items from pretrained weights
# Freezing layer 'model.23.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# AMP: checks passed ✅
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 544.5±234.0 MB/s, size: 11.8 KB)
# train: Scanning /content/train/labels... 1518 images, 2 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 1518/1518 2.3Kit/s 0.7s
# train: New cache created: /content/train/labels.cache
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 434.1±266.0 MB/s, size: 12.9 KB)
# val: Scanning /content/valid/labels... 434 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 434/434 1.7Kit/s 0.3s
# val: New cache created: /content/valid/labels.cache
# Plotting labels to /content/runs/detect/train4/labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.001667, momentum=0.9) with parameter groups 81 weight(decay=0.0), 88 weight(decay=0.0005), 87 bias(decay=0.0)
# Image sizes 640 train, 640 val
# Using 2 dataloader workers
# Logging results to /content/runs/detect/train4
# Starting training for 60 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/60      4.06G     0.8615      1.084      1.008         95        640: 100% ━━━━━━━━━━━━ 95/95 2.0it/s 47.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 14/14 1.5it/s 9.6s
#                    all        434       2461      0.941      0.929      0.966      0.762
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        2/60      4.52G     0.8201     0.5801     0.9745         89        640: 100% ━━━━━━━━━━━━ 95/95 3.2it/s 29.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 14/14 4.3it/s 3.2s
#                    all        434       2461      0.874      0.931       0.92      0.703
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        3/60      4.56G     0.8039     0.5469     0.9723        223        640: 100% ━━━━━━━━━━━━ 95/95 3.2it/s 29.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 14/14 4.5it/s 3.1s
#                    all        434       2461      0.944      0.941      0.971      0.775
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        4/60       4.6G     0.7979     0.5261     0.9686        123        640: 100% ━━━━━━━━━━━━ 95/95 3.3it/s 29.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 14/14 3.7it/s 3.8s
#                    all        434       2461      0.961      0.947      0.979      0.788
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        5/60      4.63G     0.7895     0.5016      0.961        172        640: 100% ━━━━━━━━━━━━ 95/95 3.3it/s 28.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 14/14 4.7it/s 3.0s
#                    all        434       2461      0.959      0.952       0.98       0.79
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        6/60      4.68G     0.7659     0.4735     0.9529        149        640: 100% ━━━━━━━━━━━━ 95/95 3.3it/s 28.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 14/14 3.7it/s 3.8s
#                    all        434       2461      0.963      0.945      0.981      0.801
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        7/60      4.72G     0.7451     0.4678      0.947        128        640: 100% ━━━━━━━━━━━━ 95/95 3.3it/s 28.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 14/14 4.7it/s 3.0s
#                    all        434       2461       0.96       0.96      0.982      0.816
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        8/60      4.76G     0.7438     0.4601      0.948        146        640: 100% ━━━━━━━━━━━━ 95/95 3.3it/s 28.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 14/14 3.7it/s 3.8s
#                    all        434       2461      0.964      0.966      0.985      0.794
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        9/60      4.79G     0.7479     0.4629     0.9465        126        640: 100% ━━━━━━━━━━━━ 95/95 3.3it/s 28.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 14/14 4.7it/s 3.0s
#                    all        434       2461      0.959      0.952       0.98      0.803
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       10/60      4.84G     0.7366     0.4364     0.9402        101        640: 100% ━━━━━━━━━━━━ 95/95 3.2it/s 29.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 14/14 3.8it/s 3.7s
#                    all        434       2461       0.96      0.957      0.985      0.823
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       11/60      4.88G     0.7295     0.4363     0.9342        125        640: 100% ━━━━━━━━━━━━ 95/95 3.3it/s 28.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 14/14 4.7it/s 3.0s
#                    all        434       2461      0.967      0.966      0.985      0.832
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       12/60      4.92G     0.7033     0.4109     0.9271        166        640: 100% ━━━━━━━━━━━━ 95/95 3.3it/s 28.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 14/14 3.7it/s 3.7s
#                    all        434       2461      0.964      0.963      0.985      0.829
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       13/60      4.95G     0.7042     0.4197     0.9235        125        640: 100% ━━━━━━━━━━━━ 95/95 3.3it/s 28.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 14/14 4.7it/s 3.0s
#                    all        434       2461      0.968      0.965      0.987      0.826
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       14/60      4.99G     0.6978     0.4124     0.9222        175        640: 100% ━━━━━━━━━━━━ 95/95 3.3it/s 28.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 14/14 3.9it/s 3.6s
#                    all        434       2461      0.964      0.974      0.988      0.829
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       15/60      5.04G     0.7151     0.4103     0.9253        133        640: 100% ━━━━━━━━━━━━ 95/95 3.3it/s 28.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 14/14 4.7it/s 3.0s
#                    all        434       2461      0.969       0.97      0.986      0.839
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       16/60      5.07G     0.6967     0.4031     0.9188        108        640: 100% ━━━━━━━━━━━━ 95/95 3.3it/s 29.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 14/14 3.7it/s 3.8s
#                    all        434       2461      0.977      0.959      0.988      0.818
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       17/60      5.11G     0.7039     0.4006       0.92        149        640: 100% ━━━━━━━━━━━━ 95/95 3.3it/s 28.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 14/14 4.6it/s 3.0s
#                    all        434       2461      0.966       0.97      0.986      0.827
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       18/60      5.15G     0.6873     0.3966     0.9187         89        640: 100% ━━━━━━━━━━━━ 95/95 3.2it/s 29.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 14/14 3.5it/s 4.0s
#                    all        434       2461      0.971      0.976      0.988      0.821
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       19/60      5.19G      0.675       0.39     0.9098        100        640: 100% ━━━━━━━━━━━━ 95/95 3.3it/s 29.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 14/14 4.6it/s 3.1s
#                    all        434       2461      0.963      0.977      0.988      0.825
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       20/60      5.23G     0.6723     0.3875     0.9116        153        640: 100% ━━━━━━━━━━━━ 95/95 3.3it/s 28.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 14/14 3.8it/s 3.7s
#                    all        434       2461      0.972      0.973      0.989      0.832
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       21/60      5.27G     0.6787     0.3891     0.9155         73        640: 100% ━━━━━━━━━━━━ 95/95 3.3it/s 28.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 14/14 4.7it/s 3.0s
#                    all        434       2461      0.976      0.969      0.987       0.83
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       22/60      5.31G      0.678     0.3894     0.9159        149        640: 100% ━━━━━━━━━━━━ 95/95 3.3it/s 29.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 14/14 3.9it/s 3.5s
#                    all        434       2461      0.973      0.967      0.988      0.838
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       23/60      5.35G     0.6641     0.3754     0.9123        221        640: 100% ━━━━━━━━━━━━ 95/95 3.3it/s 28.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 14/14 4.7it/s 3.0s
#                    all        434       2461      0.968      0.976      0.989      0.848
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       24/60      5.39G     0.6685     0.3783     0.9116        155        640: 100% ━━━━━━━━━━━━ 95/95 3.3it/s 29.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 14/14 4.1it/s 3.4s
#                    all        434       2461      0.971      0.972      0.988      0.844
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       25/60      5.43G     0.6753     0.3715     0.9082        116        640: 100% ━━━━━━━━━━━━ 95/95 3.3it/s 28.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 14/14 4.6it/s 3.0s
#                    all        434       2461      0.968      0.981      0.988      0.851
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       26/60      5.47G     0.6662     0.3685     0.9089        180        640: 100% ━━━━━━━━━━━━ 95/95 3.3it/s 29.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 14/14 4.2it/s 3.3s
#                    all        434       2461      0.971      0.974      0.988      0.843
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       27/60      5.51G     0.6605     0.3656     0.9074        112        640: 100% ━━━━━━━━━━━━ 95/95 3.2it/s 29.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 14/14 4.6it/s 3.0s
#                    all        434       2461      0.975      0.972       0.99      0.831
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       28/60      5.55G     0.6612     0.3682     0.9131         78        640: 100% ━━━━━━━━━━━━ 95/95 3.2it/s 29.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 14/14 4.5it/s 3.1s
#                    all        434       2461      0.968      0.977      0.989      0.836
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       29/60      5.59G     0.6441     0.3586     0.8996        118        640: 100% ━━━━━━━━━━━━ 95/95 3.3it/s 28.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 14/14 4.7it/s 3.0s
#                    all        434       2461      0.974      0.976       0.99      0.853
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       30/60      5.76G     0.6515     0.3643     0.9082        132        640: 100% ━━━━━━━━━━━━ 95/95 3.2it/s 29.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 14/14 4.5it/s 3.1s
#                    all        434       2461      0.969      0.981      0.989      0.847
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       31/60       5.8G     0.6513     0.3568     0.9037        153        640: 100% ━━━━━━━━━━━━ 95/95 3.3it/s 28.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 14/14 4.7it/s 3.0s
#                    all        434       2461      0.961      0.984      0.988      0.854
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       32/60      5.84G      0.641     0.3536     0.9041         98        640: 100% ━━━━━━━━━━━━ 95/95 3.2it/s 30.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 14/14 4.7it/s 3.0s
#                    all        434       2461       0.97      0.976      0.988      0.856
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       33/60      5.88G     0.6409     0.3545     0.8964        149        640: 100% ━━━━━━━━━━━━ 95/95 3.3it/s 29.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 14/14 4.4it/s 3.2s
#                    all        434       2461       0.97      0.979       0.99      0.854
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       34/60      5.92G     0.6343     0.3488     0.8987        166        640: 100% ━━━━━━━━━━━━ 95/95 3.3it/s 29.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 14/14 4.8it/s 2.9s
#                    all        434       2461      0.969       0.98      0.989      0.855
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       35/60      5.96G     0.6375     0.3415     0.9008        115        640: 100% ━━━━━━━━━━━━ 95/95 3.2it/s 29.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 14/14 4.1it/s 3.4s
#                    all        434       2461      0.971      0.977      0.989      0.855
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       36/60         6G     0.6441     0.3465     0.9016        218        640: 100% ━━━━━━━━━━━━ 95/95 3.3it/s 28.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 14/14 4.7it/s 3.0s
#                    all        434       2461      0.968      0.985       0.99      0.849
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       37/60      6.03G     0.6304     0.3394     0.9005        108        640: 100% ━━━━━━━━━━━━ 95/95 3.3it/s 28.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 14/14 4.2it/s 3.3s
#                    all        434       2461       0.97       0.98      0.989      0.853
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       38/60      6.08G     0.6323     0.3457     0.8995        130        640: 100% ━━━━━━━━━━━━ 95/95 3.3it/s 29.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 14/14 4.7it/s 3.0s
#                    all        434       2461      0.969      0.977       0.99      0.848
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       39/60      6.12G     0.6317     0.3399     0.8956        151        640: 100% ━━━━━━━━━━━━ 95/95 3.3it/s 28.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 14/14 4.0it/s 3.5s
#                    all        434       2461      0.973      0.981       0.99      0.859
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       40/60      6.16G     0.6194      0.332     0.8926         92        640: 100% ━━━━━━━━━━━━ 95/95 3.3it/s 28.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 14/14 4.7it/s 3.0s
#                    all        434       2461       0.97      0.983       0.99      0.854
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       41/60      6.19G     0.6295     0.3348     0.8961        102        640: 100% ━━━━━━━━━━━━ 95/95 3.3it/s 28.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 14/14 3.8it/s 3.7s
#                    all        434       2461      0.969      0.981      0.989       0.85
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       42/60      6.24G      0.609     0.3276     0.8903         82        640: 100% ━━━━━━━━━━━━ 95/95 3.3it/s 28.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 14/14 4.8it/s 2.9s
#                    all        434       2461       0.97      0.982       0.99      0.858
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       43/60      6.28G      0.614     0.3275     0.8912        161        640: 100% ━━━━━━━━━━━━ 95/95 3.2it/s 29.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 14/14 3.9it/s 3.6s
#                    all        434       2461      0.971      0.976       0.99      0.853
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       44/60      6.32G     0.6154     0.3256     0.8925         91        640: 100% ━━━━━━━━━━━━ 95/95 3.3it/s 28.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 14/14 4.8it/s 2.9s
#                    all        434       2461      0.967      0.983       0.99      0.854
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       45/60      6.46G     0.6039     0.3175     0.8873        143        640: 100% ━━━━━━━━━━━━ 95/95 3.2it/s 29.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 14/14 3.8it/s 3.7s
#                    all        434       2461      0.971       0.98       0.99       0.86
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       46/60       6.5G     0.6049     0.3199       0.89        125        640: 100% ━━━━━━━━━━━━ 95/95 3.3it/s 28.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 14/14 4.7it/s 3.0s
#                    all        434       2461       0.97      0.983       0.99      0.856
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       47/60      6.54G     0.5955     0.3146     0.8835        116        640: 100% ━━━━━━━━━━━━ 95/95 3.3it/s 29.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 14/14 3.6it/s 3.9s
#                    all        434       2461      0.973      0.977       0.99      0.855
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       48/60      6.58G      0.606     0.3138     0.8865        229        640: 100% ━━━━━━━━━━━━ 95/95 3.2it/s 29.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 14/14 4.6it/s 3.1s
#                    all        434       2461      0.966      0.984       0.99      0.859
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       49/60      6.62G     0.5949     0.3085     0.8877        101        640: 100% ━━━━━━━━━━━━ 95/95 3.2it/s 30.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 14/14 4.6it/s 3.0s
#                    all        434       2461      0.969      0.986       0.99      0.864
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       50/60      6.66G     0.5947      0.309      0.884        126        640: 100% ━━━━━━━━━━━━ 95/95 3.2it/s 29.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 14/14 4.3it/s 3.2s
#                    all        434       2461      0.969      0.983       0.99      0.862
# Closing dataloader mosaic
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       51/60       6.7G     0.5843     0.2958     0.8744         59        640: 100% ━━━━━━━━━━━━ 95/95 3.0it/s 31.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 14/14 4.7it/s 3.0s
#                    all        434       2461       0.98      0.978       0.99      0.859
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       52/60      6.74G     0.5676      0.286     0.8732         52        640: 100% ━━━━━━━━━━━━ 95/95 3.4it/s 27.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 14/14 3.9it/s 3.6s
#                    all        434       2461      0.974      0.983       0.99      0.861
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       53/60      6.78G     0.5702     0.2851     0.8699         76        640: 100% ━━━━━━━━━━━━ 95/95 3.4it/s 27.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 14/14 4.8it/s 2.9s
#                    all        434       2461      0.971      0.983       0.99      0.864
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       54/60      6.82G     0.5618      0.283     0.8728         78        640: 100% ━━━━━━━━━━━━ 95/95 3.4it/s 27.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 14/14 3.9it/s 3.6s
#                    all        434       2461      0.968      0.987       0.99      0.864
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       55/60      6.86G     0.5581      0.275     0.8693        100        640: 100% ━━━━━━━━━━━━ 95/95 3.5it/s 27.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 14/14 4.7it/s 3.0s
#                    all        434       2461      0.967      0.986       0.99      0.866
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       56/60      7.15G     0.5503     0.2756      0.863         85        640: 100% ━━━━━━━━━━━━ 95/95 3.4it/s 27.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 14/14 4.1it/s 3.5s
#                    all        434       2461      0.977      0.975       0.99      0.862
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       57/60      7.18G     0.5518      0.271     0.8693         67        640: 100% ━━━━━━━━━━━━ 95/95 3.4it/s 27.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 14/14 4.7it/s 3.0s
#                    all        434       2461      0.975      0.976       0.99      0.865
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       58/60      7.23G     0.5444     0.2714     0.8618         66        640: 100% ━━━━━━━━━━━━ 95/95 3.4it/s 28.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 14/14 4.4it/s 3.2s
#                    all        434       2461      0.971      0.984       0.99      0.867
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       59/60      7.27G     0.5503     0.2725      0.864         40        640: 100% ━━━━━━━━━━━━ 95/95 3.3it/s 28.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 14/14 4.6it/s 3.0s
#                    all        434       2461      0.974      0.981       0.99      0.866
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       60/60      7.31G     0.5429     0.2656     0.8607         78        640: 100% ━━━━━━━━━━━━ 95/95 3.3it/s 28.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 14/14 4.2it/s 3.3s
#                    all        434       2461      0.973      0.982       0.99      0.868
#
# 60 epochs completed in 0.551 hours.
# Optimizer stripped from /content/runs/detect/train4/weights/last.pt, 19.2MB
# Optimizer stripped from /content/runs/detect/train4/weights/best.pt, 19.2MB
#
# Validating /content/runs/detect/train4/weights/best.pt...
# Ultralytics 8.3.204 🚀 Python-3.12.11 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# YOLO11s summary (fused): 100 layers, 9,413,574 parameters, 0 gradients, 21.3 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 14/14 2.9it/s 4.9s
#                    all        434       2461      0.973      0.982       0.99      0.868
#                  green        352        899      0.972       0.99      0.989      0.872
#                 purple        323       1562      0.974      0.974      0.992      0.864
# Speed: 0.2ms preprocess, 3.7ms inference, 0.0ms loss, 2.0ms postprocess per image
# Results saved to /content/runs/detect/train4
# 💡 Learn more at https://docs.ultralytics.com/modes/train

# %% [markdown]
# The training algorithm will parse the images in the training and validation directories and then start training the model. At the end of each training epoch, the program runs the model on the validation dataset and reports the resulting mAP, precision, and recall. As training continues, the mAP should generally increase with each epoch. Training will end once it goes through the number of epochs specified by `epochs`.
#
# > **NOTE:** Make sure to allow training to run to completion, because an optimizer runs at the end of training that strips out unneeded layers from the model.
#
# The best trained model weights will be saved in `content/runs/detect/train/weights/best.pt`. Additional information about training is saved in the `content/runs/detect/train` folder, including a `results.png` file that shows how loss, precision, recall, and mAP progressed over each epoch.

# %% [markdown]
# #6.&nbsp;Test Model

# %% [markdown]
# The model has been trained; now it's time to test it! The commands below run the model on the images in the validation folder and then display the results for the first 10 images. This is a good way to confirm your model is working as expected. Click Play on the blocks below to see how your model performs.

# %%
# !yolo detect predict model=runs/detect/train/weights/best.pt source=data/validation/images save=True
# Out:
# Ultralytics 8.3.204 🚀 Python-3.12.11 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# YOLO11s summary (fused): 100 layers, 9,413,574 parameters, 0 gradients, 21.3 GFLOPs
#
# image 1/434 /content/data/validation/images/snap000500971805_png.rf.bd2f33d0258f7f4e70f2341dc3ee72fb.jpg: 480x640 1 purple, 55.5ms
# image 2/434 /content/data/validation/images/snap001802600258_png.rf.742671f02a867920da0d6f3091b3f3bd.jpg: 480x640 1 green, 12.3ms
# image 3/434 /content/data/validation/images/snap004330810267_png.rf.19c88181ed810cdc914f20c9b051675c.jpg: 480x640 1 green, 2 purples, 12.3ms
# image 4/434 /content/data/validation/images/snap005242313296_png.rf.6e6e360eabde4407ddd40f8aa474a52e.jpg: 480x640 1 green, 12.3ms
# image 5/434 /content/data/validation/images/snap006214482095_png.rf.46fb84fef99ce56ebc4a281417ce8029.jpg: 480x640 1 green, 12.3ms
# image 6/434 /content/data/validation/images/snap010180251469_png.rf.af7aecd7de2e0b757503988c7dab7a69.jpg: 480x640 1 green, 12.3ms
# image 7/434 /content/data/validation/images/snap011811603232_png.rf.f6069af7e284c7f8306033a82df27d10.jpg: 480x640 1 green, 3 purples, 12.3ms
# image 8/434 /content/data/validation/images/snap016204864255_png.rf.762408620f4b07cb413f823379242e99.jpg: 480x640 1 green, 12.3ms
# image 9/434 /content/data/validation/images/snap017327956871_png.rf.b35e6bf42603f236d8582dc2563ea97f.jpg: 480x640 1 green, 1 purple, 12.3ms
# image 10/434 /content/data/validation/images/snap018711825780_png.rf.6fafc9b8e277a51a6ddebb6a58c656f4.jpg: 480x640 1 green, 1 purple, 12.3ms
# image 11/434 /content/data/validation/images/snap022313247157_png.rf.0af6853a237a6b8e5b44a05a5180bd3f.jpg: 480x640 1 green, 12.3ms
# image 12/434 /content/data/validation/images/snap023439182974_png.rf.f4e20ca1f6247ef4d79bbf1496987c98.jpg: 480x640 4 greens, 9 purples, 12.3ms
# image 13/434 /content/data/validation/images/snap023873004408_png.rf.2170ad3b8ccd94c403533adec9445661.jpg: 480x640 2 purples, 12.3ms
# image 14/434 /content/data/validation/images/snap025420170364_png.rf.3475aa8fafaee84334f4bc7de9bf5867.jpg: 480x640 2 purples, 12.3ms
# image 15/434 /content/data/validation/images/snap028331617079_png.rf.e22bc82e6e222271ff74fe8d73dd545a.jpg: 480x640 5 greens, 9 purples, 12.3ms
# image 16/434 /content/data/validation/images/snap028944362327_png.rf.ede704ad9261cdc2fdd800e7818ee81e.jpg: 480x640 1 green, 5 purples, 12.3ms
# image 17/434 /content/data/validation/images/snap030046747634_png.rf.ffc420225ea2907019a9bce47b5468ee.jpg: 480x640 1 purple, 12.3ms
# image 18/434 /content/data/validation/images/snap038606611939_png.rf.ece142d449de33e56e89f14b4cbe1da2.jpg: 480x640 4 greens, 11 purples, 12.3ms
# image 19/434 /content/data/validation/images/snap042058960350_png.rf.35e22cf85880650282703b76d1cb38da.jpg: 480x640 1 green, 2 purples, 7.8ms
# image 20/434 /content/data/validation/images/snap044281446560_png.rf.1364ed23318a45f3836efb876b10b029.jpg: 480x640 4 greens, 8 purples, 7.8ms
# image 21/434 /content/data/validation/images/snap046407129937_png.rf.35f97927698a2fc8a44fcdbf032413eb.jpg: 480x640 1 green, 8.6ms
# image 22/434 /content/data/validation/images/snap047344662910_png.rf.1ce00ff1eb809c92b4a9176adfdec56d.jpg: 480x640 6 greens, 11 purples, 7.8ms
# image 23/434 /content/data/validation/images/snap047400279886_png.rf.a5b7844425fbb1c8f6959a186adf479e.jpg: 480x640 1 green, 7.8ms
# image 24/434 /content/data/validation/images/snap048288643071_png.rf.a31dcb5a12181fa61841219e891477b8.jpg: 480x640 1 purple, 7.8ms
# image 25/434 /content/data/validation/images/snap049715552600_png.rf.c7b7f7f0d3fbb914a5aa2649b4070ea1.jpg: 480x640 4 greens, 7 purples, 7.8ms
# image 26/434 /content/data/validation/images/snap049749306253_png.rf.badc7283ceb1ff255c67ded4353eba7c.jpg: 480x640 1 green, 3 purples, 7.8ms
# image 27/434 /content/data/validation/images/snap054393498839_png.rf.48d6e213df72302f33a57fa50421ee9e.jpg: 480x640 6 greens, 11 purples, 7.8ms
# image 28/434 /content/data/validation/images/snap055506014046_png.rf.18f763cb22d95f235a987b28b37ba209.jpg: 480x640 6 greens, 5 purples, 7.8ms
# image 29/434 /content/data/validation/images/snap056768879463_png.rf.d3b9bb237ed9711159e98b9277c6dcfb.jpg: 480x640 1 green, 7.8ms
# image 30/434 /content/data/validation/images/snap062945804049_png.rf.adb0c4533ff4e9ebaba842dce4ddacca.jpg: 480x640 1 green, 2 purples, 8.7ms
# image 31/434 /content/data/validation/images/snap064516769461_png.rf.667df752e3bbc4e3e02aa869f5f16dfc.jpg: 480x640 2 greens, 1 purple, 7.4ms
# image 32/434 /content/data/validation/images/snap064750206859_png.rf.e5065191b3ce37d23d00de34802f88de.jpg: 480x640 1 green, 8.4ms
# image 33/434 /content/data/validation/images/snap064928296561_png.rf.34ec2b5926d1581bae45e4b4ddd3d1ab.jpg: 480x640 1 green, 7.1ms
# image 34/434 /content/data/validation/images/snap065122595489_png.rf.311c451dddca8166ef973df6b289eb95.jpg: 480x640 1 purple, 6.9ms
# image 35/434 /content/data/validation/images/snap070046362648_png.rf.2c2ae73b7c5ce4303931941bdf726909.jpg: 480x640 1 purple, 7.0ms
# image 36/434 /content/data/validation/images/snap070393105887_png.rf.e060537ff7a446cfbfa7b8b68d51a36a.jpg: 480x640 4 greens, 3 purples, 6.9ms
# image 37/434 /content/data/validation/images/snap073928541782_png.rf.f76318ff5436b05c532d8e2aeddef1cc.jpg: 480x640 1 green, 2 purples, 7.3ms
# image 38/434 /content/data/validation/images/snap076307505885_png.rf.9d4ac1af7a06844065093a51a7cda2ad.jpg: 480x640 7 greens, 18 purples, 7.7ms
# image 39/434 /content/data/validation/images/snap076882025862_png.rf.b68da01e366a598151a445243e07750e.jpg: 480x640 1 purple, 7.4ms
# image 40/434 /content/data/validation/images/snap078154123045_png.rf.19f31181145dbe7224c0879d6546a780.jpg: 480x640 3 greens, 5 purples, 7.0ms
# image 41/434 /content/data/validation/images/snap083034327188_png.rf.f24ab59705bf18464fb248fcc1f67434.jpg: 480x640 3 purples, 7.1ms
# image 42/434 /content/data/validation/images/snap087056882720_png.rf.4b162391599d6d69bb4c2ad873b616df.jpg: 480x640 7 greens, 12 purples, 7.0ms
# image 43/434 /content/data/validation/images/snap095162018241_png.rf.ff65a63011c72fa7fe9094a2739a1958.jpg: 480x640 5 greens, 10 purples, 7.2ms
# image 44/434 /content/data/validation/images/snap103304579965_png.rf.771aa44524861b8f6685ee9df6156ab3.jpg: 480x640 1 green, 7.5ms
# image 45/434 /content/data/validation/images/snap104325406330_png.rf.f6957bf2d771152b43a76e9a36fea810.jpg: 480x640 1 purple, 7.2ms
# image 46/434 /content/data/validation/images/snap106361409760_png.rf.560c176d64858fd1aa2426a0fb13cde4.jpg: 480x640 1 green, 7.1ms
# image 47/434 /content/data/validation/images/snap111102819468_png.rf.21f5d7b60ca7784f4bc239d95af7408c.jpg: 480x640 2 greens, 2 purples, 7.0ms
# image 48/434 /content/data/validation/images/snap112951589207_png.rf.183db4d1a13502c8a5226a58e295ec78.jpg: 480x640 1 green, 7.2ms
# image 49/434 /content/data/validation/images/snap114309866815_png.rf.cc3577fb3fcef81598e7545bae0a7623.jpg: 480x640 1 green, 3 purples, 6.9ms
# image 50/434 /content/data/validation/images/snap115537529669_png.rf.19e4ac0d595cc5b8d3a52cf01ac1771e.jpg: 480x640 2 purples, 7.1ms
# image 51/434 /content/data/validation/images/snap118757557611_png.rf.af7dc644508934a9b284a1c6c3ee3b4e.jpg: 480x640 1 green, 2 purples, 10.5ms
# image 52/434 /content/data/validation/images/snap122748258595_png.rf.edc692b23d7c0b8285583ca496bd78e6.jpg: 480x640 1 green, 2 purples, 9.7ms
# image 53/434 /content/data/validation/images/snap124752900533_png.rf.bd062b6c2e7bc68cdb31299f97a1521b.jpg: 480x640 4 greens, 7 purples, 7.0ms
# image 54/434 /content/data/validation/images/snap128799268822_png.rf.705a9968591677a47a9a76172581b019.jpg: 480x640 9 greens, 17 purples, 7.2ms
# image 55/434 /content/data/validation/images/snap132543452035_png.rf.5ef481135825bc227968b7e5277bc097.jpg: 480x640 1 green, 2 purples, 7.0ms
# image 56/434 /content/data/validation/images/snap132744744688_png.rf.2ccf20c32d9a60f516cfebb97439ce89.jpg: 480x640 1 green, 2 purples, 7.1ms
# image 57/434 /content/data/validation/images/snap137492517922_png.rf.5dd6e2e46bd5957fa4730121a7b6eb05.jpg: 480x640 2 greens, 3 purples, 11.2ms
# image 58/434 /content/data/validation/images/snap138867843198_png.rf.eb449fc887da25999d1c4ebe7e26fba1.jpg: 480x640 1 green, 2 purples, 12.9ms
# image 59/434 /content/data/validation/images/snap144920819186_png.rf.69ba5872d37cd0e7311427dadc33c445.jpg: 480x640 6 greens, 11 purples, 7.1ms
# image 60/434 /content/data/validation/images/snap146390978670_png.rf.d2deeea47f59362d690e5f8195a50e6c.jpg: 480x640 7 greens, 11 purples, 7.3ms
# image 61/434 /content/data/validation/images/snap147527596334_png.rf.64bf3069d93fb07ed684a1a2add6d037.jpg: 480x640 2 greens, 3 purples, 7.1ms
# image 62/434 /content/data/validation/images/snap148540796825_png.rf.c1b4d8abf770074d5437f495c46c00e5.jpg: 480x640 6 greens, 9 purples, 7.3ms
# image 63/434 /content/data/validation/images/snap151123836586_png.rf.e555e670d0b8a07a671aaabae69137eb.jpg: 480x640 6 greens, 11 purples, 7.0ms
# image 64/434 /content/data/validation/images/snap151817889716_png.rf.d7d7b683329cd4a88e95bfcb9ebba367.jpg: 480x640 1 purple, 7.1ms
# image 65/434 /content/data/validation/images/snap158001128984_png.rf.2dc561bd1d26b01bdba07bc75bdb57b0.jpg: 480x640 5 greens, 11 purples, 7.1ms
# image 66/434 /content/data/validation/images/snap161166849430_png.rf.c48b1b1460a0610a91bcbbef5e6efcb5.jpg: 480x640 6 greens, 11 purples, 11.3ms
# image 67/434 /content/data/validation/images/snap161335089952_png.rf.59ede5c0d7bea5336000150f15654a87.jpg: 480x640 1 green, 9.1ms
# image 68/434 /content/data/validation/images/snap162543084130_png.rf.e1ba77b983be157da4d25b747cd5ccd2.jpg: 480x640 4 greens, 4 purples, 8.0ms
# image 69/434 /content/data/validation/images/snap164655749457_png.rf.88d39ceb085a49caa9becef80f240436.jpg: 480x640 1 green, 8.2ms
# image 70/434 /content/data/validation/images/snap168866861387_png.rf.084956cbe2a45c4e3ea2ec57df4e5942.jpg: 480x640 2 greens, 2 purples, 7.4ms
# image 71/434 /content/data/validation/images/snap169696212735_png.rf.36e7ab1b8c9e46fc8964ffad81939c1d.jpg: 480x640 1 green, 2 purples, 7.6ms
# image 72/434 /content/data/validation/images/snap172208564052_png.rf.a52af68c37130e1c424929ddc784f7a9.jpg: 480x640 3 greens, 7 purples, 7.5ms
# image 73/434 /content/data/validation/images/snap172752697671_png.rf.34f98a8108b2a7d33a60ed3314fbe178.jpg: 480x640 1 green, 3 purples, 7.0ms
# image 74/434 /content/data/validation/images/snap181616795616_png.rf.7b9c335e89da4976303d9cf70b3dd4da.jpg: 480x640 1 green, 7.2ms
# image 75/434 /content/data/validation/images/snap183244366552_png.rf.f6d7b6469b11c13dc70ce9a740585ec3.jpg: 480x640 1 green, 2 purples, 7.0ms
# image 76/434 /content/data/validation/images/snap183673931562_png.rf.d7232905c4add14c16058f27d7aa75e7.jpg: 480x640 2 greens, 5 purples, 7.0ms
# image 77/434 /content/data/validation/images/snap185133321325_png.rf.3e1d1940a84d1ff11b7cd614a23690a8.jpg: 480x640 3 greens, 5 purples, 7.0ms
# image 78/434 /content/data/validation/images/snap186883411993_png.rf.e721a99b99a702f0359c2e63d2758d61.jpg: 480x640 2 greens, 6 purples, 9.8ms
# image 79/434 /content/data/validation/images/snap188987912201_png.rf.9c40510f08d46bbd1d26117ece0dea06.jpg: 480x640 7 purples, 10.0ms
# image 80/434 /content/data/validation/images/snap190037882195_png.rf.91a92d9519e32926951b3b7cfb18b6d1.jpg: 480x640 1 green, 7.5ms
# image 81/434 /content/data/validation/images/snap193585313214_png.rf.25363f5511002c9f7b05e4c2514d51cc.jpg: 480x640 1 green, 7.0ms
# image 82/434 /content/data/validation/images/snap194853750725_png.rf.83a1880f734bcdd1afa9940ed91b8b4d.jpg: 480x640 3 purples, 7.0ms
# image 83/434 /content/data/validation/images/snap198928030122_png.rf.6beb302efe28fa1edd46f93b98b65c96.jpg: 480x640 4 greens, 8 purples, 7.0ms
# image 84/434 /content/data/validation/images/snap199291449582_png.rf.4ad35acb8bef4c18099a61184b524c70.jpg: 480x640 2 greens, 8.1ms
# image 85/434 /content/data/validation/images/snap202504634935_png.rf.f82e7fee6704a0a890c07462f88869ad.jpg: 480x640 3 greens, 3 purples, 7.2ms
# image 86/434 /content/data/validation/images/snap206911613100_png.rf.0326e801257b5c8aa59ae5b8b303cba4.jpg: 480x640 6 greens, 9 purples, 7.2ms
# image 87/434 /content/data/validation/images/snap207600540409_png.rf.744d52f6834be79da47f3e4b6c906e61.jpg: 480x640 1 green, 3 purples, 9.4ms
# image 88/434 /content/data/validation/images/snap208957112020_png.rf.a3ad12a3a3ac0cf1aec1821cc7b27883.jpg: 480x640 5 greens, 10 purples, 7.0ms
# image 89/434 /content/data/validation/images/snap209411200633_png.rf.f77e167ed00ed378e250ab9424194414.jpg: 480x640 4 purples, 7.1ms
# image 90/434 /content/data/validation/images/snap212415268984_png.rf.f5e73dd191a0051f35aebe01e994ad67.jpg: 480x640 1 green, 6.9ms
# image 91/434 /content/data/validation/images/snap213524157510_png.rf.33f635d14f71e4d131fdb1a21bf9c92e.jpg: 480x640 2 greens, 3 purples, 6.9ms
# image 92/434 /content/data/validation/images/snap214764699526_png.rf.df83b6ae4028d777564a92eae9c317f5.jpg: 480x640 1 green, 3 purples, 6.8ms
# image 93/434 /content/data/validation/images/snap216572160995_png.rf.8a3ae74122992b85286c87dd93fd29ef.jpg: 480x640 1 purple, 7.0ms
# image 94/434 /content/data/validation/images/snap220924879298_png.rf.e6f12f3029d2455287dc389c70f6e637.jpg: 480x640 7 greens, 11 purples, 7.4ms
# image 95/434 /content/data/validation/images/snap222172572440_png.rf.659c02f924e8161f5577915b1e61c70a.jpg: 480x640 5 greens, 9 purples, 7.0ms
# image 96/434 /content/data/validation/images/snap230844493160_png.rf.4f4a197175c17ba56b3baeca935b098f.jpg: 480x640 4 greens, 5 purples, 7.3ms
# image 97/434 /content/data/validation/images/snap230962115018_png.rf.fc6081e1d8a96e7e89be76e36e79afea.jpg: 480x640 2 greens, 8.1ms
# image 98/434 /content/data/validation/images/snap238288011358_png.rf.f6172ca4fefc6f3751ce65bb495b93fe.jpg: 480x640 5 greens, 10 purples, 6.9ms
# image 99/434 /content/data/validation/images/snap241060912321_png.rf.bef00f1db66e9fda54a1a0014201a8f0.jpg: 480x640 1 green, 3 purples, 6.9ms
# image 100/434 /content/data/validation/images/snap241176277967_png.rf.ae0d30d2ac17e2fcebc79b4bfb73ab9c.jpg: 480x640 6 greens, 19 purples, 7.2ms
# image 101/434 /content/data/validation/images/snap241850541118_png.rf.2cef7c216cd32dfe5c598af6140c46d7.jpg: 480x640 1 green, 2 purples, 7.0ms
# image 102/434 /content/data/validation/images/snap254440470262_png.rf.646107ba8c74ecf6437de2f5871c3b0d.jpg: 480x640 7 greens, 11 purples, 6.9ms
# image 103/434 /content/data/validation/images/snap256519197310_png.rf.44aadbec3e39dd79faead3f00cdeea2a.jpg: 480x640 7 greens, 13 purples, 7.9ms
# image 104/434 /content/data/validation/images/snap257415208223_png.rf.d467e714cc88748e3e838ace7d55ec42.jpg: 480x640 4 greens, 9 purples, 7.2ms
# image 105/434 /content/data/validation/images/snap257645207726_png.rf.98b07cc286610d19528d0d4a02d40577.jpg: 480x640 1 purple, 8.9ms
# image 106/434 /content/data/validation/images/snap260427670574_png.rf.ca7ca49d5eefb555c2b9599833f71535.jpg: 480x640 7 purples, 6.9ms
# image 107/434 /content/data/validation/images/snap262857739491_png.rf.05dc3a91a3c15dd6d52fc5e194581ab2.jpg: 480x640 1 green, 7.4ms
# image 108/434 /content/data/validation/images/snap263464045707_png.rf.918825c31d2abf125c412c39b1ccbfca.jpg: 480x640 1 green, 7.1ms
# image 109/434 /content/data/validation/images/snap266682354981_png.rf.c402739ead4c9e69ea719be4ee609026.jpg: 480x640 7 greens, 10 purples, 6.9ms
# image 110/434 /content/data/validation/images/snap267480732734_png.rf.f187e7eb283feedf0140425182ece7fb.jpg: 480x640 1 purple, 6.8ms
# image 111/434 /content/data/validation/images/snap268416113923_png.rf.329c926f6f5908a707127ca8d22beca6.jpg: 480x640 9 greens, 17 purples, 6.8ms
# image 112/434 /content/data/validation/images/snap268938794632_png.rf.3b4f002cf78f2b58088a5e3f8cc3388d.jpg: 480x640 1 green, 6.9ms
# image 113/434 /content/data/validation/images/snap269639168987_png.rf.6a6ad37a1b41439b944b542f9ebe4003.jpg: 480x640 4 greens, 7 purples, 6.8ms
# image 114/434 /content/data/validation/images/snap271716322916_png.rf.1514f3d8c6ab9fd287c1552f0befaee7.jpg: 480x640 1 green, 3 purples, 6.8ms
# image 115/434 /content/data/validation/images/snap272139743668_png.rf.e0e73c0223e6ae6690cf48fe719a7e93.jpg: 480x640 1 green, 6.9ms
# image 116/434 /content/data/validation/images/snap279340740751_png.rf.620014254d7b7cee3a45e2adc665e441.jpg: 480x640 1 purple, 7.0ms
# image 117/434 /content/data/validation/images/snap284816729323_png.rf.caf78586ee90bfcf2c61a43089cdbd9b.jpg: 480x640 1 green, 2 purples, 6.8ms
# image 118/434 /content/data/validation/images/snap286821076933_png.rf.04fdf2922431d5b76bc3e44f714c87f7.jpg: 480x640 4 greens, 10 purples, 6.8ms
# image 119/434 /content/data/validation/images/snap287300156377_png.rf.d6f9df986efcb2820852213fdc49142d.jpg: 480x640 1 green, 3 purples, 7.0ms
# image 120/434 /content/data/validation/images/snap288811344491_png.rf.7724ae83a8f25debf184a3b17891b5e9.jpg: 480x640 2 greens, 2 purples, 6.9ms
# image 121/434 /content/data/validation/images/snap292147348219_png.rf.761aaa4a53ad422467ab6afb64858a11.jpg: 480x640 1 green, 1 purple, 8.8ms
# image 122/434 /content/data/validation/images/snap295037777796_png.rf.469be20878c1ef9e97469d06b01f4fe0.jpg: 480x640 1 green, 2 purples, 12.3ms
# image 123/434 /content/data/validation/images/snap295285361505_png.rf.f8998e980bac978f0a6d7d250c3741d9.jpg: 480x640 2 greens, 10.2ms
# image 124/434 /content/data/validation/images/snap296608732392_png.rf.905ba8d3f383d74d21b349ca26521c9f.jpg: 480x640 6 greens, 5 purples, 7.0ms
# image 125/434 /content/data/validation/images/snap297014523914_png.rf.0ca9ab67347241a6b3e5c8d7c12263cc.jpg: 480x640 9 greens, 17 purples, 9.5ms
# image 126/434 /content/data/validation/images/snap298514191518_png.rf.904dffcb30ec64398cfd96449eab5d22.jpg: 480x640 3 greens, 8 purples, 6.9ms
# image 127/434 /content/data/validation/images/snap298517243389_png.rf.0903613253389bc87b3efd140690f930.jpg: 480x640 5 greens, 3 purples, 6.8ms
# image 128/434 /content/data/validation/images/snap298676711312_png.rf.1603cfbb72af081f338f8e9577793f75.jpg: 480x640 1 green, 2 purples, 6.9ms
# image 129/434 /content/data/validation/images/snap299904507932_png.rf.ca41d098d1005ce2ca57ac041cd959a0.jpg: 480x640 1 purple, 6.9ms
# image 130/434 /content/data/validation/images/snap301656676871_png.rf.79c78fbed317cad4aa5a054fa8f4de66.jpg: 480x640 1 green, 2 purples, 6.8ms
# image 131/434 /content/data/validation/images/snap305414620696_png.rf.2803ecfdc56dc828658cca9b3477bada.jpg: 480x640 4 greens, 8 purples, 6.9ms
# image 132/434 /content/data/validation/images/snap308962381239_png.rf.8cd967222394d6849c30c595982a6fb9.jpg: 480x640 1 purple, 7.0ms
# image 133/434 /content/data/validation/images/snap311076790179_png.rf.518c81af74d3afd4970f9249bb40da24.jpg: 480x640 1 purple, 6.8ms
# image 134/434 /content/data/validation/images/snap312187395827_png.rf.502fc8fa4e8e478e09bc76aad4552099.jpg: 480x640 7 greens, 8 purples, 8.3ms
# image 135/434 /content/data/validation/images/snap315961277022_png.rf.2fd6504d1c966ac3e22c0258bd9bef74.jpg: 480x640 1 green, 1 purple, 7.0ms
# image 136/434 /content/data/validation/images/snap317880156019_png.rf.b6151d272792103fd9c3d91ea2cacf8f.jpg: 480x640 2 greens, 1 purple, 7.1ms
# image 137/434 /content/data/validation/images/snap320446952482_png.rf.f50c7fb4557ddb711afa6aab8ad0bc3e.jpg: 480x640 5 greens, 1 purple, 7.0ms
# image 138/434 /content/data/validation/images/snap321054739072_png.rf.d7f160807875eacdd737d7c8c723ee77.jpg: 480x640 4 greens, 6 purples, 7.2ms
# image 139/434 /content/data/validation/images/snap321599736128_png.rf.0bb494a1377214b9d8dc1caa79b807ac.jpg: 480x640 5 greens, 4 purples, 7.1ms
# image 140/434 /content/data/validation/images/snap323789980943_png.rf.9e35a58bbce52dfbc3570bfbfa20d4ab.jpg: 480x640 1 green, 2 purples, 7.1ms
# image 141/434 /content/data/validation/images/snap324115938727_png.rf.f57b7b6a3bad165c8e18a5b5aaf55c3d.jpg: 480x640 1 purple, 7.1ms
# image 142/434 /content/data/validation/images/snap325729133424_png.rf.bfc9fbdf3d4a8198b77fe29dd3d5aeba.jpg: 480x640 7 purples, 7.0ms
# image 143/434 /content/data/validation/images/snap333227222020_png.rf.9eecc3f9b133d69204d81cd23afedfd3.jpg: 480x640 1 green, 7.0ms
# image 144/434 /content/data/validation/images/snap337246684243_png.rf.293039eb2565ddb56f50123258e52c3b.jpg: 480x640 2 greens, 4 purples, 6.9ms
# image 145/434 /content/data/validation/images/snap337731020586_png.rf.a40054c89748e38fd2a915fd7d422a50.jpg: 480x640 2 greens, 6.9ms
# image 146/434 /content/data/validation/images/snap341313421204_png.rf.4fe08039271868bedd7ff8698f0704ff.jpg: 480x640 1 green, 4 purples, 9.4ms
# image 147/434 /content/data/validation/images/snap342980458585_png.rf.99838522cc0abe407a8255a5595bb3ce.jpg: 480x640 1 green, 7 purples, 8.7ms
# image 148/434 /content/data/validation/images/snap347731417473_png.rf.74abe3e547679a4ad50c81e431ba7c95.jpg: 480x640 1 green, 2 purples, 7.4ms
# image 149/434 /content/data/validation/images/snap351237794398_png.rf.0242469acf906ac7676a704a3652ec39.jpg: 480x640 5 greens, 9 purples, 7.3ms
# image 150/434 /content/data/validation/images/snap351768370708_png.rf.029101aef6999514c3fdf6ea6a060019.jpg: 480x640 5 greens, 1 purple, 7.2ms
# image 151/434 /content/data/validation/images/snap353048571409_png.rf.d9cfe8add6a04df91672b900d76d3968.jpg: 480x640 2 greens, 2 purples, 7.1ms
# image 152/434 /content/data/validation/images/snap354889146284_png.rf.446ef945334ad20f4d8dc93eacf40889.jpg: 480x640 1 purple, 7.3ms
# image 153/434 /content/data/validation/images/snap356623673610_png.rf.a20bf97c24157a8a69a282061076aa6f.jpg: 480x640 1 green, 2 purples, 7.1ms
# image 154/434 /content/data/validation/images/snap357470231834_png.rf.89e1797902fb0620893c92ed9edfb6b2.jpg: 480x640 1 green, 7.0ms
# image 155/434 /content/data/validation/images/snap357678190024_png.rf.62b3668a83876c70eff06abc2f7dcf57.jpg: 480x640 2 greens, 3 purples, 7.0ms
# image 156/434 /content/data/validation/images/snap357787873477_png.rf.4fc78e29f49c94e4dc8099352c159e07.jpg: 480x640 1 green, 7.1ms
# image 157/434 /content/data/validation/images/snap358878034625_png.rf.a7f946dbf8c2b5536e37654afe5fdcce.jpg: 480x640 6 greens, 10 purples, 7.0ms
# image 158/434 /content/data/validation/images/snap359560799411_png.rf.cba9393b1aa3e393fd01df0bdcfb759e.jpg: 480x640 5 greens, 6.9ms
# image 159/434 /content/data/validation/images/snap360478060805_png.rf.98d7a098b8e94d7d314342413cb000b4.jpg: 480x640 1 green, 2 purples, 7.0ms
# image 160/434 /content/data/validation/images/snap363132278512_png.rf.265e0dbe4aae9ff3db912dac6ac28890.jpg: 480x640 6 greens, 10 purples, 7.1ms
# image 161/434 /content/data/validation/images/snap363901443396_png.rf.dcf15e0eee052eee9f193706f003e573.jpg: 480x640 1 purple, 7.0ms
# image 162/434 /content/data/validation/images/snap365855181851_png.rf.25c2e4b344c316640fd707dca4e19b31.jpg: 480x640 1 green, 7.1ms
# image 163/434 /content/data/validation/images/snap367117024411_png.rf.3ddb1eadef7ab1021ea4f5e95d1e858c.jpg: 480x640 5 greens, 9 purples, 6.9ms
# image 164/434 /content/data/validation/images/snap370537047429_png.rf.bb3ff49e2499d8e238a239b09bb54d1a.jpg: 480x640 1 purple, 6.9ms
# image 165/434 /content/data/validation/images/snap380073981289_png.rf.921e2085f26be309b0a13b9cfb7373e2.jpg: 480x640 1 purple, 6.8ms
# image 166/434 /content/data/validation/images/snap388388148708_png.rf.eb14c583d0db059f1380b2812ed062a3.jpg: 480x640 1 purple, 6.9ms
# image 167/434 /content/data/validation/images/snap390685433975_png.rf.c23b9261b961e16248c3d88a68befa36.jpg: 480x640 1 purple, 8.0ms
# image 168/434 /content/data/validation/images/snap391371116343_png.rf.6e93c03e7ac4319ce21d83500703e2df.jpg: 480x640 4 greens, 8 purples, 6.9ms
# image 169/434 /content/data/validation/images/snap391857002176_png.rf.f811f80b29b6c7381c7b5e837a793406.jpg: 480x640 3 purples, 7.0ms
# image 170/434 /content/data/validation/images/snap392469451994_png.rf.effc1e1514920814d067e7e70fca36bf.jpg: 480x640 3 greens, 7 purples, 7.1ms
# image 171/434 /content/data/validation/images/snap393556988613_png.rf.ef08384ae785b2b53573a0ef7b172450.jpg: 480x640 1 green, 2 purples, 6.9ms
# image 172/434 /content/data/validation/images/snap394902858844_png.rf.5e220dae93dba056c4aa8cdc2f55357b.jpg: 480x640 5 greens, 9 purples, 6.9ms
# image 173/434 /content/data/validation/images/snap395095500773_png.rf.02999134bf9391492d88a07b4a51d629.jpg: 480x640 1 green, 7.6ms
# image 174/434 /content/data/validation/images/snap395248673291_png.rf.29d8d422c43b126dc8d05e544838a38a.jpg: 480x640 1 purple, 6.9ms
# image 175/434 /content/data/validation/images/snap397421537392_png.rf.a3b0b317102b15febc17c2122ab81471.jpg: 480x640 1 green, 7.3ms
# image 176/434 /content/data/validation/images/snap397631368119_png.rf.d7d63b2c266348026db08f715aee5932.jpg: 480x640 1 green, 7.0ms
# image 177/434 /content/data/validation/images/snap399030835459_png.rf.99e8e567aaa0afcf1c2397f853214bf7.jpg: 480x640 1 green, 3 purples, 6.9ms
# image 178/434 /content/data/validation/images/snap402249791199_png.rf.fe96f58b8dd85cba06bc3773d812463d.jpg: 480x640 1 purple, 7.0ms
# image 179/434 /content/data/validation/images/snap404719378409_png.rf.014da10d970f9e6a114c9b8ae6628eb6.jpg: 480x640 4 greens, 7 purples, 7.0ms
# image 180/434 /content/data/validation/images/snap406332524203_png.rf.08a6a4ea2551c96631c72d61e58bb291.jpg: 480x640 3 greens, 6 purples, 7.0ms
# image 181/434 /content/data/validation/images/snap411530808551_png.rf.aeed62e27f72e0b685de8cba061a4e44.jpg: 480x640 1 green, 7.1ms
# image 182/434 /content/data/validation/images/snap411873150734_png.rf.69f333741e4af3291c06bcf1eb41733e.jpg: 480x640 4 greens, 7 purples, 7.0ms
# image 183/434 /content/data/validation/images/snap412420779483_png.rf.e6f88b580591d1ebc919352a8abe1600.jpg: 480x640 1 green, 1 purple, 6.9ms
# image 184/434 /content/data/validation/images/snap412685068346_png.rf.4547794ebf742470a2541b16f6065413.jpg: 480x640 1 green, 6.8ms
# image 185/434 /content/data/validation/images/snap418427127105_png.rf.85851c389ab4c33e162bcbc88de90b7f.jpg: 480x640 1 purple, 7.0ms
# image 186/434 /content/data/validation/images/snap425909887198_png.rf.44059d03c04162183b80df68ef353e03.jpg: 480x640 3 greens, 11 purples, 6.8ms
# image 187/434 /content/data/validation/images/snap429165688086_png.rf.74b13a07666993942b0f7f3bd9224f3a.jpg: 480x640 6 greens, 11 purples, 8.6ms
# image 188/434 /content/data/validation/images/snap429892891845_png.rf.d493b7123e2fd679472103311964f18a.jpg: 480x640 6 greens, 9 purples, 10.9ms
# image 189/434 /content/data/validation/images/snap429910471495_png.rf.befe3c07c7972bb10e905bc93444ba15.jpg: 480x640 2 greens, 8.1ms
# image 190/434 /content/data/validation/images/snap433775549520_png.rf.5ed5121bed129fe4bc6f5914a6eb8498.jpg: 480x640 1 purple, 7.1ms
# image 191/434 /content/data/validation/images/snap434714292883_png.rf.d15c450565c1b2dcdd08ca99c2fcfeeb.jpg: 480x640 3 greens, 9 purples, 7.9ms
# image 192/434 /content/data/validation/images/snap437107775354_png.rf.258ad480595ecef244c5ee70023e15e9.jpg: 480x640 1 green, 12.0ms
# image 193/434 /content/data/validation/images/snap437539121432_png.rf.7fe5721e019f8d0ede9b76ea720910a5.jpg: 480x640 1 green, 10.6ms
# image 194/434 /content/data/validation/images/snap438432351764_png.rf.214783cdd84d979514556da5e0509c5e.jpg: 480x640 1 green, 7.0ms
# image 195/434 /content/data/validation/images/snap438932103272_png.rf.9f36e37d4aa53491e19003f15abe1a70.jpg: 480x640 5 greens, 9 purples, 6.9ms
# image 196/434 /content/data/validation/images/snap439035910294_png.rf.5313818e6f2288383aee5583f3a7dfee.jpg: 480x640 6 greens, 9 purples, 6.8ms
# image 197/434 /content/data/validation/images/snap441045968955_png.rf.a70317a076f17d32fa760a5b9b777d0c.jpg: 480x640 8 greens, 14 purples, 7.1ms
# image 198/434 /content/data/validation/images/snap441146462667_png.rf.73016a06f29652e004a6818158daf312.jpg: 480x640 1 green, 7.1ms
# image 199/434 /content/data/validation/images/snap442534580200_png.rf.1137425fb63dbdc24a04151a08eeae7d.jpg: 480x640 1 green, 6.9ms
# image 200/434 /content/data/validation/images/snap442594295295_png.rf.dfb5950ef6e57c9d285cceef8c4946eb.jpg: 480x640 1 green, 1 purple, 6.8ms
# image 201/434 /content/data/validation/images/snap445028604223_png.rf.9a14ae54da7e8cb3540a34dbac4a2da4.jpg: 480x640 1 green, 3 purples, 6.8ms
# image 202/434 /content/data/validation/images/snap449295552473_png.rf.445bb0ba2d21f1c1250b65417e478a1a.jpg: 480x640 1 green, 6.8ms
# image 203/434 /content/data/validation/images/snap449494969330_png.rf.3662dfb87162b2d5b3afd7fabb4b093f.jpg: 480x640 6 greens, 10 purples, 8.2ms
# image 204/434 /content/data/validation/images/snap450173285410_png.rf.a6296bd509635b8559618a3c51226c2b.jpg: 480x640 4 purples, 7.2ms
# image 205/434 /content/data/validation/images/snap453820435437_png.rf.5fd9a1da1b01c3451844b329c53e1289.jpg: 480x640 1 purple, 7.7ms
# image 206/434 /content/data/validation/images/snap456698448257_png.rf.bfc8e7a80abcc836bce7278f30071fa8.jpg: 480x640 1 purple, 7.1ms
# image 207/434 /content/data/validation/images/snap458104506596_png.rf.45def6f3830a657c75627994c405c80d.jpg: 480x640 4 greens, 9 purples, 9.0ms
# image 208/434 /content/data/validation/images/snap458391320968_png.rf.4454d64fdc173032a47c6056f1b61762.jpg: 480x640 1 green, 3 purples, 7.2ms
# image 209/434 /content/data/validation/images/snap458796573166_png.rf.61bdc8e5c5b2e01f78dd390544c7542c.jpg: 480x640 1 green, 7.1ms
# image 210/434 /content/data/validation/images/snap460552356799_png.rf.f8fe7489f163a5218d330eaad8227b4b.jpg: 480x640 1 green, 7.0ms
# image 211/434 /content/data/validation/images/snap475635571262_png.rf.e2a1f7d3ded5be1d4b107909863c2776.jpg: 480x640 1 green, 7.1ms
# image 212/434 /content/data/validation/images/snap477158762946_png.rf.7823255c13c527fe6749b43e30e2e757.jpg: 480x640 1 green, 3 purples, 7.1ms
# image 213/434 /content/data/validation/images/snap479729971902_png.rf.21d8834867ebbbdb8f09ba340a89080c.jpg: 480x640 1 green, 7.1ms
# image 214/434 /content/data/validation/images/snap481386539000_png.rf.e2f68291662365a9b744f0da6c960dc4.jpg: 480x640 1 purple, 7.0ms
# image 215/434 /content/data/validation/images/snap482530064680_png.rf.cfe4fb4b580aeefa0bdf6f903ccebce4.jpg: 480x640 1 purple, 7.1ms
# image 216/434 /content/data/validation/images/snap486625723857_png.rf.fdf45bf742f1e6eb1c1b9b87c7d7515a.jpg: 480x640 1 green, 2 purples, 7.0ms
# image 217/434 /content/data/validation/images/snap492064158435_png.rf.563466ec8c2bcce78b11992ddf270846.jpg: 480x640 1 green, 7.0ms
# image 218/434 /content/data/validation/images/snap505911572812_png.rf.0dc4b3dab6449718fd595e6521c19480.jpg: 480x640 1 purple, 8.1ms
# image 219/434 /content/data/validation/images/snap506461572709_png.rf.ba7914f4da0217b1fe150c96708b76f3.jpg: 480x640 3 greens, 7 purples, 7.9ms
# image 220/434 /content/data/validation/images/snap508221724905_png.rf.d061b0842f0f526702c2f7d1979bc351.jpg: 480x640 1 green, 7.1ms
# image 221/434 /content/data/validation/images/snap509834243227_png.rf.be1587f271bd0223098986dfbf69687d.jpg: 480x640 1 green, 7.1ms
# image 222/434 /content/data/validation/images/snap512716873014_png.rf.23c383ca12d9cf6a1ba3a8bbe8229ddd.jpg: 480x640 1 purple, 7.1ms
# image 223/434 /content/data/validation/images/snap517717391197_png.rf.6903d4cc543639467110c11db64ade30.jpg: 480x640 1 purple, 7.0ms
# image 224/434 /content/data/validation/images/snap520402168143_png.rf.156b91ecc3be2978df4ed976167f50d4.jpg: 480x640 1 green, 3 purples, 7.0ms
# image 225/434 /content/data/validation/images/snap522206204248_png.rf.f4dcf41a92985c1c613f4c97e32cf118.jpg: 480x640 2 greens, 7.1ms
# image 226/434 /content/data/validation/images/snap526811616651_png.rf.6d379aa4ea34cdd0c9a8f5729b235ccf.jpg: 480x640 1 green, 7.2ms
# image 227/434 /content/data/validation/images/snap529222820676_png.rf.3d56d25faa7e41cfd108c5397a3a2946.jpg: 480x640 1 green, 7.2ms
# image 228/434 /content/data/validation/images/snap529756697630_png.rf.0413fc103234dd0cd36f7554e72ae2df.jpg: 480x640 1 green, 7.1ms
# image 229/434 /content/data/validation/images/snap535915969493_png.rf.068d2c03353903e3beb3b5496815d4f1.jpg: 480x640 5 greens, 4 purples, 7.0ms
# image 230/434 /content/data/validation/images/snap540995086724_png.rf.dc03873aafc60960623c052b18cc9232.jpg: 480x640 1 green, 4 purples, 7.0ms
# image 231/434 /content/data/validation/images/snap542428860598_png.rf.09be015ada2669501ad506ae751d5721.jpg: 480x640 1 purple, 7.3ms
# image 232/434 /content/data/validation/images/snap542484193595_png.rf.2a3f22dce38b532474be25d262625a58.jpg: 480x640 1 green, 7.0ms
# image 233/434 /content/data/validation/images/snap543271886420_png.rf.610c2d9a8f3f51052c1441f7b4dee5d9.jpg: 480x640 3 greens, 9 purples, 8.9ms
# image 234/434 /content/data/validation/images/snap544090490467_png.rf.4c30008d30faa809ad7a14a15c868c3f.jpg: 480x640 2 greens, 7.1ms
# image 235/434 /content/data/validation/images/snap553564888602_png.rf.531dbc419f6fb56d4f36dc3af59e2a45.jpg: 480x640 1 purple, 6.9ms
# image 236/434 /content/data/validation/images/snap553630298602_png.rf.36c0fee6fbfd1cc725bd70f2f0cbb6f6.jpg: 480x640 1 green, 7.6ms
# image 237/434 /content/data/validation/images/snap554183320458_png.rf.767043dbc92a9954a8762c676e33bf5a.jpg: 480x640 9 greens, 17 purples, 7.1ms
# image 238/434 /content/data/validation/images/snap556396410392_png.rf.7391179a82ce416018d7fab1851bc0f2.jpg: 480x640 1 purple, 7.2ms
# image 239/434 /content/data/validation/images/snap564495410208_png.rf.3b8b0d1bb3aa1dad861105248b14f723.jpg: 480x640 1 purple, 7.0ms
# image 240/434 /content/data/validation/images/snap565336908373_png.rf.29b4ecbc134c42ce57d254cb77da8942.jpg: 480x640 1 green, 7.1ms
# image 241/434 /content/data/validation/images/snap573421220088_png.rf.c9524aa3236af80145fd8e563fe23c9e.jpg: 480x640 1 green, 7.3ms
# image 242/434 /content/data/validation/images/snap573532940160_png.rf.3ed06210f78c4e2f36b6ee26987f9f17.jpg: 480x640 1 green, 1 purple, 7.0ms
# image 243/434 /content/data/validation/images/snap573644247335_png.rf.ade16fd17a30b77ec7bc8d47da874668.jpg: 480x640 1 green, 7.1ms
# image 244/434 /content/data/validation/images/snap577892965280_png.rf.8da10fee2e4e12aabc93656411a8f164.jpg: 480x640 4 greens, 4 purples, 7.8ms
# image 245/434 /content/data/validation/images/snap582678517663_png.rf.d638bba386ca659a9b4e5945e6423cd3.jpg: 480x640 5 greens, 9 purples, 8.3ms
# image 246/434 /content/data/validation/images/snap582961102230_png.rf.2e9896737e300fb3f3be711f36b163c7.jpg: 480x640 2 greens, 6 purples, 8.1ms
# image 247/434 /content/data/validation/images/snap586007974996_png.rf.f4161259ca0f4a411d843ec92653f2f2.jpg: 480x640 3 greens, 8.0ms
# image 248/434 /content/data/validation/images/snap589381117379_png.rf.c3d447da2bb1d8453d220f510cf72b3c.jpg: 480x640 1 green, 7.9ms
# image 249/434 /content/data/validation/images/snap594942856006_png.rf.4cb80c4c130f141aa51bc0e42ea42a21.jpg: 480x640 1 green, 1 purple, 7.8ms
# image 250/434 /content/data/validation/images/snap595648735613_png.rf.8be94c588f9176ebcb62f678847c7633.jpg: 480x640 6 greens, 11 purples, 7.9ms
# image 251/434 /content/data/validation/images/snap598729702601_png.rf.aa133bf6dc0e1ef66f3f2a3ce44a88d2.jpg: 480x640 1 green, 10.6ms
# image 252/434 /content/data/validation/images/snap599261308753_png.rf.4fae396c9289273399823c6082fe82e9.jpg: 480x640 2 greens, 1 purple, 8.6ms
# image 253/434 /content/data/validation/images/snap599410827447_png.rf.43bd3bdd2e7fbcd1b784618b135980bf.jpg: 480x640 1 green, 7.4ms
# image 254/434 /content/data/validation/images/snap608339490926_png.rf.45301d2eb7697192bb2756ddc4a839d9.jpg: 480x640 1 green, 2 purples, 14.2ms
# image 255/434 /content/data/validation/images/snap611268335511_png.rf.e611ef3bcebcb4d6f43150bb73ab0295.jpg: 480x640 2 greens, 3 purples, 11.6ms
# image 256/434 /content/data/validation/images/snap612664021217_png.rf.e59cd04a41eb7ef910897b1d30d0723a.jpg: 480x640 4 purples, 12.9ms
# image 257/434 /content/data/validation/images/snap613043746208_png.rf.d3ffb6d3e0534de463b1d8c2e5ca43c3.jpg: 480x640 1 purple, 13.1ms
# image 258/434 /content/data/validation/images/snap616451005308_png.rf.f60fefcac15199f81c7afb612eab99ec.jpg: 480x640 6 greens, 7 purples, 14.8ms
# image 259/434 /content/data/validation/images/snap618510721036_png.rf.a3959f34f754d516b15783e9a0649161.jpg: 480x640 1 green, 2 purples, 12.9ms
# image 260/434 /content/data/validation/images/snap620159514909_png.rf.d26adc44888a6f566d65591b177a608c.jpg: 480x640 1 green, 17.6ms
# image 261/434 /content/data/validation/images/snap620298792438_png.rf.319f6ee495b41bd34cf067a9c1df4fee.jpg: 480x640 1 green, 17.9ms
# image 262/434 /content/data/validation/images/snap620456716612_png.rf.adb90efc91def1b636973a83e8cf86ce.jpg: 480x640 1 green, 13.3ms
# image 263/434 /content/data/validation/images/snap622275281873_png.rf.fd3891e7cffc683295ead24a457892f3.jpg: 480x640 1 green, 2 purples, 11.6ms
# image 264/434 /content/data/validation/images/snap625610661638_png.rf.db1d91de200da3b0980bf96661022776.jpg: 480x640 2 greens, 5 purples, 9.5ms
# image 265/434 /content/data/validation/images/snap625850729021_png.rf.22ca5b07c418bae9208baa0fe139a4e7.jpg: 480x640 1 green, 14.3ms
# image 266/434 /content/data/validation/images/snap626727713691_png.rf.ba8e7ae56b148ffe2ab6494a4356b0f9.jpg: 480x640 1 green, 2 purples, 9.8ms
# image 267/434 /content/data/validation/images/snap629036243355_png.rf.d8d54ecd07c90bc75d12741a89974ba0.jpg: 480x640 4 greens, 10 purples, 10.2ms
# image 268/434 /content/data/validation/images/snap630787543002_png.rf.0635d52d31ed294ae33ddf33a700b79a.jpg: 480x640 5 greens, 9 purples, 10.2ms
# image 269/434 /content/data/validation/images/snap632470978592_png.rf.119ac52bc2430102e14ec97f93f51e15.jpg: 480x640 1 purple, 10.7ms
# image 270/434 /content/data/validation/images/snap632556018907_png.rf.7d1112d3a90e221b3dbe5a7ebeba6b2d.jpg: 480x640 1 green, 9.2ms
# image 271/434 /content/data/validation/images/snap637886802776_png.rf.0d5ae8567536103a36b8b88c4672c2f7.jpg: 480x640 1 purple, 9.2ms
# image 272/434 /content/data/validation/images/snap637980653453_png.rf.1e4627b50870c9986a29a9b66e54c21b.jpg: 480x640 4 purples, 9.2ms
# image 273/434 /content/data/validation/images/snap641805385922_png.rf.97f19fcce7561c7acb3518f2e13bd592.jpg: 480x640 2 greens, 1 purple, 12.4ms
# image 274/434 /content/data/validation/images/snap642914837048_png.rf.d7242be7cf8afa00fdb747c50bf3db9b.jpg: 480x640 1 green, 10.1ms
# image 275/434 /content/data/validation/images/snap643768033038_png.rf.57c95ef08fc444ae41a0de885f77c47b.jpg: 480x640 5 greens, 9 purples, 9.8ms
# image 276/434 /content/data/validation/images/snap644293052607_png.rf.b72070a4daba3a386e2382b2a0f18366.jpg: 480x640 1 green, 10.6ms
# image 277/434 /content/data/validation/images/snap644608223344_png.rf.41b80d08942bee941604a619efcab125.jpg: 480x640 6 greens, 10 purples, 9.9ms
# image 278/434 /content/data/validation/images/snap647188642910_png.rf.3ccedec4a34283cc186a13695429ca4e.jpg: 480x640 1 green, 9.7ms
# image 279/434 /content/data/validation/images/snap649286176381_png.rf.528c0c72c068a08c571dce69cfce0abf.jpg: 480x640 1 purple, 14.7ms
# image 280/434 /content/data/validation/images/snap651266442982_png.rf.60c3523fa05a26c939ecb9a427c3f415.jpg: 480x640 4 greens, 10 purples, 16.0ms
# image 281/434 /content/data/validation/images/snap655937435497_png.rf.69fc8b3eddb28492b0c177a54712b04d.jpg: 480x640 2 greens, 9.6ms
# image 282/434 /content/data/validation/images/snap660351505482_png.rf.040d266e1a951740ac14702e5e3d5ef5.jpg: 480x640 1 purple, 9.6ms
# image 283/434 /content/data/validation/images/snap660748373241_png.rf.2b26ab451cd4630066e845965f08e2f5.jpg: 480x640 1 purple, 9.9ms
# image 284/434 /content/data/validation/images/snap662380579701_png.rf.e11637af178fa79a3a08995bb4559c85.jpg: 480x640 1 green, 7 purples, 9.4ms
# image 285/434 /content/data/validation/images/snap665126308500_png.rf.62ccea81c6c4b2402ad2c7054762f7f8.jpg: 480x640 1 green, 2 purples, 11.4ms
# image 286/434 /content/data/validation/images/snap666162207863_png.rf.8a78d8b8966b43de6def581d0fbf14b4.jpg: 480x640 9 greens, 17 purples, 9.6ms
# image 287/434 /content/data/validation/images/snap667768041587_png.rf.368580a6c3e049b84575a22f7ebdf6b2.jpg: 480x640 1 purple, 9.7ms
# image 288/434 /content/data/validation/images/snap677974787114_png.rf.a49668cf061cfaaed4ee2fc635caeac7.jpg: 480x640 1 green, 2 purples, 9.8ms
# image 289/434 /content/data/validation/images/snap679944260429_png.rf.6f720aaee8ff43f324b97997cf283b3b.jpg: 480x640 2 greens, 9.6ms
# image 290/434 /content/data/validation/images/snap681517526499_png.rf.05f6c98c82a519bdc2d24c52cd954352.jpg: 480x640 3 greens, 5 purples, 9.7ms
# image 291/434 /content/data/validation/images/snap682050791131_png.rf.e0de1b245bb334fd585c425c522c7147.jpg: 480x640 5 greens, 10 purples, 9.5ms
# image 292/434 /content/data/validation/images/snap682454177335_png.rf.5611731b8a4d32aea7c8a104ef087b5d.jpg: 480x640 6 greens, 17 purples, 9.9ms
# image 293/434 /content/data/validation/images/snap683475023043_png.rf.058b599a8f445e1818c1260d4bdc09e9.jpg: 480x640 1 green, 11.5ms
# image 294/434 /content/data/validation/images/snap684526802017_png.rf.2b258311f1babf5809c146f90447198d.jpg: 480x640 7 greens, 17 purples, 10.0ms
# image 295/434 /content/data/validation/images/snap684575309684_png.rf.407bc37314310e438c605d24e401cb13.jpg: 480x640 6 greens, 9 purples, 9.4ms
# image 296/434 /content/data/validation/images/snap687054678931_png.rf.da66017146b7bece6c7df7e053e94de1.jpg: 480x640 1 green, 9.5ms
# image 297/434 /content/data/validation/images/snap688608946135_png.rf.fbbc4fa1e8ed3071035edd99366540bb.jpg: 480x640 1 green, 2 purples, 9.2ms
# image 298/434 /content/data/validation/images/snap691580354672_png.rf.9356b106f6ad957f18de55f7cf81092c.jpg: 480x640 1 green, 2 purples, 9.0ms
# image 299/434 /content/data/validation/images/snap696466832949_png.rf.9d94e0eb8abfe2a480c496b3f1867c23.jpg: 480x640 1 green, 2 purples, 9.0ms
# image 300/434 /content/data/validation/images/snap697934839783_png.rf.0a33dfa124ceb471b94fe1bb35c74b4d.jpg: 480x640 2 greens, 9.0ms
# image 301/434 /content/data/validation/images/snap700766315556_png.rf.8ad0b70bc8cbbac42bc9214767d7f511.jpg: 480x640 1 purple, 9.3ms
# image 302/434 /content/data/validation/images/snap703145629876_png.rf.a911bd77c83797a6c311c6cccf34266a.jpg: 480x640 1 green, 5 purples, 9.2ms
# image 303/434 /content/data/validation/images/snap703268654293_png.rf.56bf7049154e20edefae548e6d9bb10d.jpg: 480x640 1 green, 3 purples, 9.2ms
# image 304/434 /content/data/validation/images/snap709696853429_png.rf.a7b3af56e41bceab2c0bf99d3ce9eeaf.jpg: 480x640 1 green, 2 purples, 9.4ms
# image 305/434 /content/data/validation/images/snap712204675492_png.rf.479738cd052aabc1d2d8505a11e379f1.jpg: 480x640 9 greens, 17 purples, 9.9ms
# image 306/434 /content/data/validation/images/snap712482328666_png.rf.cc196d8d934712c8f52bb62106e99906.jpg: 480x640 1 green, 1 purple, 9.4ms
# image 307/434 /content/data/validation/images/snap715143150659_png.rf.e97c3dc40f66cd388ca32852266701d5.jpg: 480x640 8 greens, 15 purples, 11.0ms
# image 308/434 /content/data/validation/images/snap715237452668_png.rf.e389dd73d8e3acbc5fb9e029c9351317.jpg: 480x640 6 greens, 9 purples, 9.3ms
# image 309/434 /content/data/validation/images/snap717162570281_png.rf.a694952506a3cc436ae9bf17c2815005.jpg: 480x640 3 purples, 9.1ms
# image 310/434 /content/data/validation/images/snap721302681653_png.rf.51f83b91c381a8210814fe19e5c4c3c1.jpg: 480x640 1 green, 14.9ms
# image 311/434 /content/data/validation/images/snap723537762077_png.rf.9dfd5917323fd78bcc66cad59a820113.jpg: 480x640 1 green, 1 purple, 11.5ms
# image 312/434 /content/data/validation/images/snap724295110315_png.rf.2be9bfd00f610779fb8f9575cd33911c.jpg: 480x640 1 green, 2 purples, 10.4ms
# image 313/434 /content/data/validation/images/snap725311522539_png.rf.24a5c84c50c48b12f78a3806189d9ee4.jpg: 480x640 1 green, 2 purples, 11.3ms
# image 314/434 /content/data/validation/images/snap726990670922_png.rf.0d3b288f1ef9a9dd12b601e60116467e.jpg: 480x640 8 greens, 15 purples, 11.2ms
# image 315/434 /content/data/validation/images/snap728811315747_png.rf.8a86b13efaa962a0fd72377996185778.jpg: 480x640 2 greens, 5 purples, 9.1ms
# image 316/434 /content/data/validation/images/snap729194821028_png.rf.d1b2a775fb2719e61e933c90a7d4024c.jpg: 480x640 1 purple, 11.5ms
# image 317/434 /content/data/validation/images/snap729643247174_png.rf.6897c426e265381a2c7ee711e9a3b169.jpg: 480x640 1 green, 13.5ms
# image 318/434 /content/data/validation/images/snap730997877462_png.rf.055500c22a38e6c99dfccb2f14b4072d.jpg: 480x640 1 purple, 13.2ms
# image 319/434 /content/data/validation/images/snap737077267852_png.rf.0d10b2a61ea403090d768b38e3cb37f1.jpg: 480x640 1 green, 2 purples, 9.8ms
# image 320/434 /content/data/validation/images/snap739225720635_png.rf.ed66296c302bba0114bfa27566432cc2.jpg: 480x640 1 green, 1 purple, 12.7ms
# image 321/434 /content/data/validation/images/snap742985030964_png.rf.122a49f7e592410145b3f34266f86f7d.jpg: 480x640 1 green, 13.2ms
# image 322/434 /content/data/validation/images/snap743659218904_png.rf.fad2633c8e694403575871321e7c119b.jpg: 480x640 2 greens, 1 purple, 13.8ms
# image 323/434 /content/data/validation/images/snap743800472907_png.rf.ecd1658c8ccfd60c10a8ec4b5eef443f.jpg: 480x640 6 greens, 12 purples, 10.8ms
# image 324/434 /content/data/validation/images/snap744003835570_png.rf.697601b5a9cb6c3e89889ea82e265c24.jpg: 480x640 3 greens, 14.7ms
# image 325/434 /content/data/validation/images/snap746652525134_png.rf.ea333c178a94d7b475eec350efb43ecf.jpg: 480x640 3 greens, 6 purples, 10.6ms
# image 326/434 /content/data/validation/images/snap750742531882_png.rf.242135c09c8a1976e07258ed727efa72.jpg: 480x640 4 greens, 6 purples, 10.1ms
# image 327/434 /content/data/validation/images/snap753135957100_png.rf.8450c63037dc66a1aff4286ff7cfe98e.jpg: 480x640 1 green, 1 purple, 11.1ms
# image 328/434 /content/data/validation/images/snap754283479118_png.rf.a64f90c68f22739dfd203ab7802c46e4.jpg: 480x640 5 greens, 8 purples, 9.6ms
# image 329/434 /content/data/validation/images/snap757200801879_png.rf.8db11b832e2c2f4d790028aaa76d7920.jpg: 480x640 7 greens, 11 purples, 9.7ms
# image 330/434 /content/data/validation/images/snap759947554541_png.rf.e8e99489e0c3cc1c08e710b456342c1c.jpg: 480x640 1 green, 3 purples, 15.5ms
# image 331/434 /content/data/validation/images/snap760124904816_png.rf.582ba2f15ab052d7081f81eaca142e65.jpg: 480x640 5 greens, 6 purples, 12.4ms
# image 332/434 /content/data/validation/images/snap760473925165_png.rf.9348921470cbb9bb058b2ac8a7ee61bc.jpg: 480x640 1 green, 2 purples, 16.1ms
# image 333/434 /content/data/validation/images/snap760827580638_png.rf.365252152bcf01fef0a6e2afc3366bcf.jpg: 480x640 1 green, 2 purples, 14.1ms
# image 334/434 /content/data/validation/images/snap762450003621_png.rf.b4eae27b93db4977a1b3778db098145e.jpg: 480x640 3 greens, 5 purples, 11.0ms
# image 335/434 /content/data/validation/images/snap763852913890_png.rf.b6f13728a660011ce0f81732a36eb759.jpg: 480x640 3 greens, 4 purples, 12.2ms
# image 336/434 /content/data/validation/images/snap770622079241_png.rf.b343bac4cc5260db907825d2336e3781.jpg: 480x640 4 greens, 8 purples, 9.8ms
# image 337/434 /content/data/validation/images/snap775849734501_png.rf.ffcf329d3b5b70a225f55e39d3b810be.jpg: 480x640 1 purple, 13.2ms
# image 338/434 /content/data/validation/images/snap779384343572_png.rf.cf85a435c7ee858573ba3b3ccc4cc1d8.jpg: 480x640 5 greens, 7 purples, 11.7ms
# image 339/434 /content/data/validation/images/snap779406238967_png.rf.c8e965835eab369d9233e69c12d1bb69.jpg: 480x640 1 purple, 13.3ms
# image 340/434 /content/data/validation/images/snap782750602576_png.rf.5ddd3dcda5bee07cfef45fe216dceb74.jpg: 480x640 6 purples, 14.0ms
# image 341/434 /content/data/validation/images/snap786211861650_png.rf.c6461f565b4103433aa53393d3902805.jpg: 480x640 1 green, 12.9ms
# image 342/434 /content/data/validation/images/snap791469176566_png.rf.dff2e619195cf169ddd295db275f03c7.jpg: 480x640 5 greens, 2 purples, 12.9ms
# image 343/434 /content/data/validation/images/snap793536382782_png.rf.bb9afe6898c5d16a7841918f0b2f91c8.jpg: 480x640 2 greens, 6 purples, 13.1ms
# image 344/434 /content/data/validation/images/snap797462474349_png.rf.54d357175c84807adf0623c36571ccf1.jpg: 480x640 2 greens, 4 purples, 14.7ms
# image 345/434 /content/data/validation/images/snap801601414061_png.rf.5da086f14fcea7ddea630ce8adfa9e0e.jpg: 480x640 1 green, 2 purples, 14.5ms
# image 346/434 /content/data/validation/images/snap801696896216_png.rf.b6b928b9e3059d5117234c9bad172763.jpg: 480x640 1 green, 2 purples, 14.3ms
# image 347/434 /content/data/validation/images/snap803802984351_png.rf.4f3a8cbe49baf09019b1a8ef4456489e.jpg: 480x640 1 green, 13.3ms
# image 348/434 /content/data/validation/images/snap806589244240_png.rf.9e3557927cc26293ffe1b13a96f491d0.jpg: 480x640 1 purple, 13.0ms
# image 349/434 /content/data/validation/images/snap808189130295_png.rf.f469c5e853e2896d95f448ac69fd51b0.jpg: 480x640 4 greens, 9 purples, 14.7ms
# image 350/434 /content/data/validation/images/snap809861528721_png.rf.704ec39298c9af8db01a718e6b27e4bc.jpg: 480x640 3 greens, 5 purples, 7.4ms
# image 351/434 /content/data/validation/images/snap811278335865_png.rf.1a419817c1972ca90805249ddab85456.jpg: 480x640 1 green, 4 purples, 7.2ms
# image 352/434 /content/data/validation/images/snap813143707665_png.rf.9fe053a36e4ac9a3bf06466d726aede7.jpg: 480x640 1 green, 7.4ms
# image 353/434 /content/data/validation/images/snap813161684991_png.rf.d8fb5ab1e422f9fc4cab58c2e21a9524.jpg: 480x640 1 green, 2 purples, 7.3ms
# image 354/434 /content/data/validation/images/snap813929040599_png.rf.5ca413e3ba95041c68256cbcb1570048.jpg: 480x640 1 green, 2 purples, 7.4ms
# image 355/434 /content/data/validation/images/snap814172516399_png.rf.4cebb9de255135ae6fde52d6f72a251d.jpg: 480x640 1 green, 7.4ms
# image 356/434 /content/data/validation/images/snap816526862196_png.rf.80b839e407d63997c990c09fdff9a64e.jpg: 480x640 1 green, 4 purples, 7.1ms
# image 357/434 /content/data/validation/images/snap818120152431_png.rf.f4db0c3953fa89cf89c5f466dfa85c95.jpg: 480x640 1 green, 3 purples, 7.0ms
# image 358/434 /content/data/validation/images/snap818776509837_png.rf.e7593ff2b6b8a2e0e75382bc2fc313b4.jpg: 480x640 1 purple, 7.0ms
# image 359/434 /content/data/validation/images/snap821556991335_png.rf.29bea8157df9bb2b6778aeec39b85a68.jpg: 480x640 1 purple, 10.6ms
# image 360/434 /content/data/validation/images/snap822079616600_png.rf.4ec733b9183da0e8df6c825982e68f4a.jpg: 480x640 1 green, 3 purples, 13.5ms
# image 361/434 /content/data/validation/images/snap825373891065_png.rf.8d6c3a123fa58ff7f5ebb8a926dcc598.jpg: 480x640 1 green, 9.7ms
# image 362/434 /content/data/validation/images/snap835442059352_png.rf.04f30a2d4e38378b76b9b4adf61d856b.jpg: 480x640 1 green, 7.1ms
# image 363/434 /content/data/validation/images/snap838004424100_png.rf.8f801cd23be03eb1e3a0a9e5370318c8.jpg: 480x640 1 green, 9 purples, 7.0ms
# image 364/434 /content/data/validation/images/snap840823398750_png.rf.7ae38dce89783544e35f4154ec430a93.jpg: 480x640 5 greens, 9 purples, 7.3ms
# image 365/434 /content/data/validation/images/snap843467813377_png.rf.3f2a365b60d077b19997f84766255395.jpg: 480x640 1 purple, 7.0ms
# image 366/434 /content/data/validation/images/snap843709622855_png.rf.7ff3126c3efefc9f08790cb393bcfd88.jpg: 480x640 1 green, 2 purples, 7.0ms
# image 367/434 /content/data/validation/images/snap848170126840_png.rf.5f0dabf1e8b9016a13af623003857f95.jpg: 480x640 2 purples, 7.7ms
# image 368/434 /content/data/validation/images/snap852337627715_png.rf.0f6a35befa20a4d2a2c59d6a7dbc3663.jpg: 480x640 2 greens, 7.4ms
# image 369/434 /content/data/validation/images/snap853004164936_png.rf.4df16843b45afa22b0c02991112c041f.jpg: 480x640 1 green, 7.2ms
# image 370/434 /content/data/validation/images/snap854401017244_png.rf.e1135da67c2a1005f226bfdd76441feb.jpg: 480x640 4 greens, 6 purples, 8.1ms
# image 371/434 /content/data/validation/images/snap854635110599_png.rf.9051f869a2b5785a7573efebef781a25.jpg: 480x640 1 green, 7.5ms
# image 372/434 /content/data/validation/images/snap854897996637_png.rf.24a0d1f52e6c8d96b1fa5e547c8bd802.jpg: 480x640 1 green, 7.5ms
# image 373/434 /content/data/validation/images/snap863555521224_png.rf.8ce1f297c05864ff8f5b89699d654eae.jpg: 480x640 1 green, 2 purples, 7.4ms
# image 374/434 /content/data/validation/images/snap864761947724_png.rf.c69fb177565d45d8632be1e145742d01.jpg: 480x640 1 purple, 7.8ms
# image 375/434 /content/data/validation/images/snap864875378590_png.rf.225919c748472a6dc07db1f2324fa600.jpg: 480x640 1 green, 7.5ms
# image 376/434 /content/data/validation/images/snap865765557427_png.rf.13cbf9f627a14ec9b053f5b9d759f5bb.jpg: 480x640 2 greens, 7.2ms
# image 377/434 /content/data/validation/images/snap868249209688_png.rf.3e5b10b6f6d080250c8df732a266efcb.jpg: 480x640 6 purples, 7.1ms
# image 378/434 /content/data/validation/images/snap869053557369_png.rf.705218ec913474ff929f6a333bb655c1.jpg: 480x640 1 green, 4 purples, 7.3ms
# image 379/434 /content/data/validation/images/snap870508414071_png.rf.16aa6ced4a490ac1446cc256cf41a0db.jpg: 480x640 1 purple, 7.2ms
# image 380/434 /content/data/validation/images/snap871614024825_png.rf.7f5c560472b155f8539b7413eb4c006c.jpg: 480x640 6 greens, 10 purples, 7.2ms
# image 381/434 /content/data/validation/images/snap871896917123_png.rf.a4b1aa03bd1c3c16f3bdf905f0f9bc21.jpg: 480x640 1 green, 7.3ms
# image 382/434 /content/data/validation/images/snap881802773194_png.rf.e4572ee740e1793048143a2faa33e13a.jpg: 480x640 1 green, 8.0ms
# image 383/434 /content/data/validation/images/snap886328132600_png.rf.7c6e3dd8618d1a69c12669b33e319e5d.jpg: 480x640 1 green, 1 purple, 9.2ms
# image 384/434 /content/data/validation/images/snap886694781478_png.rf.c6ba4f8254df12881d9deea0d29d71f9.jpg: 480x640 4 greens, 5 purples, 7.3ms
# image 385/434 /content/data/validation/images/snap887448219276_png.rf.7ca9d93a42ba630d4d2c3211c16f993d.jpg: 480x640 4 purples, 7.4ms
# image 386/434 /content/data/validation/images/snap889007101387_png.rf.fefe355279888c1f292f68d720f62bea.jpg: 480x640 2 greens, 5 purples, 7.9ms
# image 387/434 /content/data/validation/images/snap889433965146_png.rf.95d44bf1e1a5ff6028bea91d645a2f50.jpg: 480x640 5 greens, 9 purples, 7.2ms
# image 388/434 /content/data/validation/images/snap890277287156_png.rf.63433f6f5ee7d084187fbd55b009661c.jpg: 480x640 1 green, 7.5ms
# image 389/434 /content/data/validation/images/snap890942965606_png.rf.c359c2679b0669522e013998919af8a7.jpg: 480x640 1 green, 4 purples, 7.6ms
# image 390/434 /content/data/validation/images/snap891618339316_png.rf.a9940081074ea76bac7ff758767140c4.jpg: 480x640 1 purple, 7.1ms
# image 391/434 /content/data/validation/images/snap891738580057_png.rf.32afbf046192886ba684d7066434e48b.jpg: 480x640 5 greens, 9 purples, 7.3ms
# image 392/434 /content/data/validation/images/snap900043208327_png.rf.dc9e57765049c377a89264e329fa0877.jpg: 480x640 2 greens, 4 purples, 7.5ms
# image 393/434 /content/data/validation/images/snap900084707111_png.rf.7dcecb5d77600017a2cc661b36d3dd22.jpg: 480x640 1 green, 7.4ms
# image 394/434 /content/data/validation/images/snap903933411412_png.rf.ad6365065d20952a7b314b4126e70910.jpg: 480x640 1 green, 7.1ms
# image 395/434 /content/data/validation/images/snap908084765224_png.rf.a6cf07486f3dadf9f80665b67f3ca839.jpg: 480x640 1 green, 7.9ms
# image 396/434 /content/data/validation/images/snap910795065189_png.rf.dc46d92de110d8100a04d58ee80a61ab.jpg: 480x640 1 green, 2 purples, 8.0ms
# image 397/434 /content/data/validation/images/snap911153333846_png.rf.d58831f2aa832fa931cfd9d5f905c420.jpg: 480x640 4 greens, 7 purples, 7.2ms
# image 398/434 /content/data/validation/images/snap912382676021_png.rf.a34172903a6e6bf90cc67aa09ac02f8b.jpg: 480x640 3 greens, 7 purples, 7.4ms
# image 399/434 /content/data/validation/images/snap913151142126_png.rf.85fbc763559a1626337a670e829e1d7c.jpg: 480x640 4 greens, 5 purples, 7.3ms
# image 400/434 /content/data/validation/images/snap919387107227_png.rf.4b0f7c85f520ab51ead92ccb7bf264c0.jpg: 480x640 1 green, 2 purples, 7.2ms
# image 401/434 /content/data/validation/images/snap920509793606_png.rf.833b5a29412c79b5c593e47aa0ba9c53.jpg: 480x640 4 greens, 7 purples, 7.1ms
# image 402/434 /content/data/validation/images/snap920803459073_png.rf.25a5357a89f75a558909a9feb8bf4df2.jpg: 480x640 1 green, 3 purples, 7.1ms
# image 403/434 /content/data/validation/images/snap922497815599_png.rf.fe419df8281bbe153d485f8b1f810ab9.jpg: 480x640 1 green, 2 purples, 9.4ms
# image 404/434 /content/data/validation/images/snap925164430368_png.rf.fdd5e99b21786092b1ad63d598fc3cdb.jpg: 480x640 1 green, 7.6ms
# image 405/434 /content/data/validation/images/snap928453426895_png.rf.98a7aac0a056c1bd6ca7cc3a6bf7a4eb.jpg: 480x640 5 greens, 6 purples, 7.0ms
# image 406/434 /content/data/validation/images/snap933075447829_png.rf.51b6b93e4635cde6aa11d2c2f991e494.jpg: 480x640 5 greens, 10 purples, 7.1ms
# image 407/434 /content/data/validation/images/snap934567255135_png.rf.09522cebe6140eeffb497277b694c4a3.jpg: 480x640 1 green, 2 purples, 7.3ms
# image 408/434 /content/data/validation/images/snap934732261850_png.rf.a9ba21ba476fb8b0bc1ceefe47c1121f.jpg: 480x640 8 greens, 12 purples, 7.5ms
# image 409/434 /content/data/validation/images/snap942694092493_png.rf.5da53dfb77cbb90db4426a16d699484e.jpg: 480x640 3 purples, 8.4ms
# image 410/434 /content/data/validation/images/snap942831287952_png.rf.98b9dfdbaa3f4526a127b154e568fe0b.jpg: 480x640 1 green, 9 purples, 7.7ms
# image 411/434 /content/data/validation/images/snap948120472673_png.rf.deab188f8f7cc9ae6696034fc4f4606f.jpg: 480x640 4 greens, 10 purples, 9.3ms
# image 412/434 /content/data/validation/images/snap952383319161_png.rf.fe00ad585a9a83a1dca779dd3bb82330.jpg: 480x640 1 green, 7.6ms
# image 413/434 /content/data/validation/images/snap952906981172_png.rf.327ae471f03793a505b316d1d91dc52c.jpg: 480x640 2 greens, 4 purples, 8.1ms
# image 414/434 /content/data/validation/images/snap959191648047_png.rf.581d41b0390c8c12f388ce4e0b02ed0a.jpg: 480x640 4 greens, 5 purples, 8.6ms
# image 415/434 /content/data/validation/images/snap960358552984_png.rf.3f5799974e9208cdd931b73793329c5d.jpg: 480x640 6 greens, 11 purples, 7.5ms
# image 416/434 /content/data/validation/images/snap962652440090_png.rf.a3104f1e1e9db8d020244a0592ac1183.jpg: 480x640 3 greens, 3 purples, 7.5ms
# image 417/434 /content/data/validation/images/snap964706358448_png.rf.33b3901d2208bdfa7919cdbe68d57fe8.jpg: 480x640 1 green, 4 purples, 7.3ms
# image 418/434 /content/data/validation/images/snap970273870041_png.rf.c4e5506f95c21ffbc415484da6ef9b8e.jpg: 480x640 1 purple, 7.2ms
# image 419/434 /content/data/validation/images/snap975037737235_png.rf.cc30b6e3f5ff1cfa73c79a3a5af2ca02.jpg: 480x640 3 greens, 10 purples, 7.1ms
# image 420/434 /content/data/validation/images/snap975501435339_png.rf.ab55f4a83c010df78112b4dbdbbeeffd.jpg: 480x640 9 greens, 18 purples, 7.6ms
# image 421/434 /content/data/validation/images/snap976058628045_png.rf.67a9970b87a8a098a8d385776bd3c46a.jpg: 480x640 1 purple, 7.2ms
# image 422/434 /content/data/validation/images/snap976282960863_png.rf.60778955e2afa6576bf6a688a8273b94.jpg: 480x640 1 green, 2 purples, 7.1ms
# image 423/434 /content/data/validation/images/snap986238972527_png.rf.8d288d3cb499b8e8179d0cd0daff5033.jpg: 480x640 4 greens, 5 purples, 7.2ms
# image 424/434 /content/data/validation/images/snap986346815284_png.rf.97df3e045da43f868468ba294cad13f7.jpg: 480x640 5 greens, 10 purples, 8.3ms
# image 425/434 /content/data/validation/images/snap987318729416_png.rf.cae1a2a7951c4fcf1668edbe2ce3b3af.jpg: 480x640 1 green, 2 purples, 7.1ms
# image 426/434 /content/data/validation/images/snap988368655591_png.rf.9c63c0021259c63a39f7e6ce53c287f7.jpg: 480x640 2 greens, 4 purples, 12.4ms
# image 427/434 /content/data/validation/images/snap990132832199_png.rf.623d0f4caf845287bd2c3278a53916fe.jpg: 480x640 1 green, 2 purples, 7.6ms
# image 428/434 /content/data/validation/images/snap991330699712_png.rf.de2dc0b13c7d443f8eb5f4ecdb99e30e.jpg: 480x640 6 greens, 7 purples, 7.0ms
# image 429/434 /content/data/validation/images/snap992209955209_png.rf.16c72b22b069601a14b6ba1951642047.jpg: 480x640 5 greens, 10 purples, 7.1ms
# image 430/434 /content/data/validation/images/snap993968821276_png.rf.27c495d137af77d2d9936fc8cdcdd93f.jpg: 480x640 2 greens, 7.4ms
# image 431/434 /content/data/validation/images/snap997553663034_png.rf.616b0a442ff28b2ff149565ac78bacad.jpg: 480x640 1 green, 2 purples, 7.2ms
# image 432/434 /content/data/validation/images/snap997762510998_png.rf.df3becddc3d45eb437e6c5046a015863.jpg: 480x640 1 green, 1 purple, 7.1ms
# image 433/434 /content/data/validation/images/snap998104928977_png.rf.13cacb31b42fcd9fe691e317c06aba09.jpg: 480x640 2 greens, 3 purples, 7.1ms
# image 434/434 /content/data/validation/images/snap999461070402_png.rf.3b19bf6c4bc02f0fb5e4183cb362b942.jpg: 480x640 1 purple, 7.5ms
# Speed: 1.8ms preprocess, 8.7ms inference, 4.1ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to /content/runs/detect/predict
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
import glob
from IPython.display import Image, display
for image_path in glob.glob(f'/content/runs/detect/predict/*.jpg')[:10]:
  display(Image(filename=image_path, height=400))
  print('\n')

# %% [markdown]
# The model should draw a box around each object of interest in each image. If it isn't doing a good job of detecting objects, here are a few tips:
#
# 1. Double-check your dataset to make sure there are no labeling errors or conflicting examples.
# 2. Increase the number of epochs used for training.
# 3. Use a larger model size (e.g. `yolo11l.pt`).
# 4. Add more images to the training dataset. See my [dataset video](https://www.youtube.com/watch?v=v0ssiOY6cfg) for tips on how to capture good training images and improve accuracy.
#
# You can also run the model on video files or other images images by uploading them to this notebook and using the above `!yolo detect predict` command, where `source` points to the location of the video file, image, or folder of images. The results will be saved in `runs/detect/predict`.
#
# Drawing boxes on images is great, but it isn't very useful in itself. It's also not very helpful to just run this models inside a Colab notebook: it's easier if we can just run it on a local computer. Continue to the next section to see how to download your newly trained model and run it on a local device.

# %% [markdown]
# #7.&nbsp;Deploy Model

# %% [markdown]
# Now that your custom model has been trained, it's ready to be downloaded and deployed in an application! YOLO models can run on a wide variety of hardware, including PCs, embedded systems, and phones. Ultralytics makes it easy to convert the YOLO models to various formats (`tflite`, `onnx`, etc.) and deploy them in a variety of environments.
#
# This section shows how to download the model and provides links to instructions for deploying it on your PC and edge devices like the Raspberry Pi.

# %% [markdown]
# ## 7.1 Download YOLO Model
#
# First, zip and download the trained model by running the code blocks below.
#
# The code creates a folder named `my_model`, moves the model weights into it, and renames them from `best.pt` to `my_model.pt`. It also adds the training results in case you want to reference them later. It then zips the folder as `my_model.zip`.

# %%
# Create "my_model" folder to store model weights and train results
# !mkdir /content/my_model
# !cp /content/runs/detect/train/weights/best.pt /content/my_model/my_model.pt
# !cp -r /content/runs/detect/train /content/my_model

# Zip into "my_model.zip"
# %cd my_model
# !zip /content/my_model.zip my_model.pt
# !zip -r /content/my_model.zip train
# %cd /content

# %%
# This takes forever for some reason, you can also just download the model from the sidebar
from google.colab import files

files.download('/content/my_model.zip')

# %% [markdown]
# ## 7.2 Deploy YOLO Model on Local Devices
#
# Next, we'll take our downloaded model and run it on a local device. This section provides instructions showing how to deploy YOLO models on various devices.
#
# I wrote a basic Python script, `yolo_detect.py`, that shows how to load a model, run inference on an image source, parse the inference results, and display boxes around each detected class in the image. The [script](https://github.com/EdjeElectronics/Train-and-Deploy-YOLO-Models/blob/main/yolo_detect.py) gives an example of how to work with Ultralytics YOLO models in Python, and it can be used as a starting point for more advanced applications.

# %% [markdown]
# ### 7.2.1 Deploy on PC (Windows, Linux, or macOS)
#
# The easiest way to run Ultralytics models on a PC is using Anaconda. Anaconda sets up a virtual Python environment and allows you to easily install Ultralytics and PyTorch. It automatically installs CUDA and cuDNN, which allows you to speed up model inference with your NVIDIA GPU.
#
# > **NOTE:** My YouTube video (link to be added) shows how to deploy your model on a PC. It walks through the following steps, so watch the video if you prefer having visual instructions.
#
# **1. Download and Install Anaconda**
#
# Go to the Anaconda download page at https://anaconda.com/download, click the “skip registration” button, and then download the package for your OS. When it's finished downloading, run the installer and click through the installation steps. You can use the default options for installation.
#
# **2. Set up virtual environment**
#
# Once it's installed, run Anaconda Prompt from the Start Bar. (If you're on macOS or Linux, just open a command terminal).
#
# Issue the following commands to create a new Python environment and activate it:
#
# ```
# conda create --name yolo-env1 python=3.12 -y
# conda activate yolo-env1
# ```
#
# Install Ultralytics (which also installs import libraries like OpenCV-Python, Numpy, and PyTorch) by issuing the following command:
#
# ```
# pip install ultralytics
# ```
#
# If you have an NVIDIA GPU, you can install the GPU-enabled version of PyTorch by issuing the following command:
#
# ```
# pip install --upgrade torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu124
# ```
#
# **3. Extract downloaded model**
# Take the `my_model.zip` file you downloaded in Step 7.1 and unzip it to a folder on your PC. In the Anaconda Prompt terminal, move into the unzipped folder using:
#
# ```
# cd path/to/folder
# ```
#
# **4. Download and run yolo_detect.py**
#
# Download the `yolo_detect.py` script into the `my_model` folder using:
#
# ```
# curl -o yolo_detect.py https://raw.githubusercontent.com/EdjeElectronics/Train-and-Deploy-YOLO-Models/refs/heads/main/yolo_detect.py
# ```
#
# Alright! We're ready to run the script. To run inference with a yolov8s model on a USB camera at 1280x720 resolution, issue:
#
# ```
# python yolo_detect.py --model my_model.pt --source usb0 --resolution 1280x720
# ```
#
# A window will appear showing a live feed from your webcam with boxes drawn around detected objects in each frame.
#
# You can also run the model on an video file, image, or folder of images. To see a full list of arguments for `yolo_detect.py`, issue `python yolo_detect.py --help` or see the [README file](https://github.com/EdjeElectronics/Train-and-Deploy-YOLO-Models/blob/main/README.md).

# %% [markdown]
# ### 7.2.2 Deploy on Raspberry Pi
#
# Keep an eye out for an article showing how to convert YOLO models to NCNN format and run them on the Raspberry Pi!

# %% [markdown]
# # 8.&nbsp;Conclusion

# %% [markdown]
# Congratulations! You've successfully trained and deployed a YOLO object detection model. 😀
#
# Next, you can extend your application beyond just drawing boxes and counting objects. Add functionality like logging the number of objects detected over time or taking a picture when certain objects are detected. Check out some example applications at our GitHub repository: https://github.com/EdjeElectronics/Train-and-Deploy-YOLO-Models
#
# Thanks for working through this notebook, and good luck with your projects!

# %% [markdown]
# # Appendix: Common Errors

# %% [markdown]
# If you run into any errors working through this notebook, please do the following:
#
#
# - Double-check that the dataset files are set up in the correct folder structure
# - Make sure there are no typos or errors in your labelmap file
# - Google search the error to look for solutions
#
# If none of those help, please submit an [Issue](https://github.com/EdjeElectronics/Train-and-Deploy-YOLO-Models/issues) on the GitHub page. In this section, I will add resolutions to common errors as they come up.
